# %%
from icecube import icetray, dataio, dataclasses, simclasses, phys_services, recclasses
import os, sys
import numpy as np
import matplotlib as mpl
from matplotlib.colors import LogNorm, Normalize
import matplotlib.pyplot as plt
import timeit as time
import math
from datetime import datetime

# %%
# Added by JP
# Define the directory of your files
files_dir = '/data/icecube/domeff_analysis/reco_sim_nominal/0000000-0000999'
# List the contents of the entire directory
file_list_aux = os.listdir(files_dir)
# Only keep those that are I3 files
file_list = [x for x in file_list_aux if '.i3.bz2' in x]
print('Total files', len(file_list))
# Out:
# Total files 966

# %%
#I would recommend you write a function that takes a frame as input 
#and returns the corrected charge for that event. 
#Inside, the function should pick the muon and loop over all the doms that have seen light, 
#and return the corrected charges of all doms, as an array. So each event gives you an array as the output.

# %%
# Now decide how many files to loop over
nfiles = 1 # This can be len(file_list)

# %%
def func(frame):
    pulses = frame['SRTInIcePulsesDOMeff'].apply(frame)
    one_dom = pulses.items()
    charge = []
    
    for i in range(len(one_dom)):  
        char = 0
        for pulse in one_dom[i][1]:
            char += pulse.charge        
        if char > 0:
            charge.append(char)
        
    gcd_file = '/cvmfs/icecube.opensciencegrid.org/data/GCD/GeoCalibDetectorStatus_IC86_Merged.i3.gz'
    gfile = dataio.I3File(gcd_file)
    gframe = gfile.pop_frame()
    geometry = gframe['I3Geometry']
    
    mydom = []
    for i in range(len(one_dom)):
        dom = geometry.omgeo[one_dom[i][0]]    
        mydom.append(dom) 
        
    mmctracks = frame['MMCTrackList']
    track = mmctracks[0].particle
    
    
    
   
    dis = np.sqrt((mydom[len(mydom)-1].position.x - mydom[0].position.x)**2 + 
                  (mydom[len(mydom)-1].position.y - mydom[0].position.y)**2
    +(mydom[len(mydom)-1].position.z - mydom[0].position.z)**2)
    
    distance = []
    for i in range(len(mydom)):
        d = phys_services.I3Calculator.cherenkov_distance(track, mydom[i].position)
        distance.append(d)
        
    corrected_charge = []
    for i in range(len(distance)):
        att_length = 50. 
        corrected = charge[i]*distance[i]
        corrected_charge.append(corrected)
    
    return corrected_charge, dis

# %%
for i in range(nfiles):
    infile = dataio.I3File(os.path.join(files_dir,file_list[i]))
    frame = infile.pop_physics()
    print(len(frame))
    print(len(func(frame)[0]))
    print('Total charge', np.sum(func(frame)[0]) )
    print('distance between first and last doms', func(frame)[1])
    print('Average charge per meter, dividing total charge over the distance of first/last dom with light', np.sum(func(frame)[0]) / func(frame)[1])
    print('Standard deviation', np.std(func(frame)[0]))
    print('Maximum corrected charge observed', np.max(func(frame)[0]) )
    print('Mean corrected charge observed', np.mean(func(frame)[0]) )
    print('Ratio',np.max(func(frame)[0])/np.mean(func(frame)[0]) )
# Out:
# 133
# 51
# Total charge 5850.190597420843
# distance f/l 173.3141056029231
# Average charge per meter, dividing total charge over the distance of first/last dom with light 33.75484399881515
# Standard deviation 79.81515272200875
# Maximum corrected charge observed 420.42546298068703
# Mean corrected charge observed 114.70961955727144
# Ratio 3.6651282133385497

# %%
for i in range(nfiles):
    with dataio.I3File(os.path.join(files_dir, file_list[i])) as infile:
        for frame in infile:
            if infile.stream.id != 'P': continue
                
            print(len(frame))
            print(len(func(frame)[0]))
            print('Total charge', np.sum(func(frame)[0]) )
            print('distance between first and last doms', func(frame)[1])
            print('Average charge per meter, dividing total charge over the distance of first/last dom with light', np.sum(func(frame)[0]) / func(frame)[1])
            print('Standard deviation', np.std(func(frame)[0]))
            print('Maximum corrected charge observed', np.max(func(frame)[0]) )
            print('Mean corrected charge observed', np.mean(func(frame)[0]) )
            print('Ratio',np.max(func(frame)[0])/np.mean(func(frame)[0]) )
            

#print(func(frame))
# Out:
# 133
# 51
# Total charge 5850.190597420843
# distance between first and last doms 173.3141056029231
# Average charge per meter, dividing total charge over the distance of first/last dom with light 33.75484399881515
# Standard deviation 79.81515272200875
# Maximum corrected charge observed 420.42546298068703
# Mean corrected charge observed 114.70961955727144
# Ratio 3.6651282133385497
# 129
# 36
# Total charge 4899.764818928101
# distance between first and last doms 334.58605968135225
# Average charge per meter, dividing total charge over the distance of first/last dom with light 14.644258710582445
# Standard deviation 94.09463146909916
# Maximum corrected charge observed 542.2863779954413
# Mean corrected charge observed 136.10457830355836
# Ratio 3.98433605066512
# 146
# 31
# Total charge 3468.7989330663177
# distance between first and last doms 1057.2395494102473
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.28099618955921
# Standard deviation 94.47281167065323
# Maximum corrected charge observed 436.15178967775745
# Mean corrected charge observed 111.89673977633282
# Ratio 3.8978060535952053
# 126
# 20
# Total charge 1510.0398739467903
# distance between first and last doms 714.6366728901108
# Average charge per meter, dividing total charge over the distance of first/last dom with light 2.1130176091298747
# Standard deviation 65.48790599786271
# Maximum corrected charge observed 249.18149610412462
# Mean corrected charge observed 75.50199369733951
# Ratio 3.3003300164894203
# 131
# 22
# Total charge 2500.242137474859
# distance between first and last doms 704.305597893962
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.549939323144905
# Standard deviation 85.91812477718334
# Maximum corrected charge observed 354.4744078045578
# Mean corrected charge observed 113.64736988522087
# Ratio 3.1190726909259956
# 127
# 30
# Total charge 2267.894305371064
# distance between first and last doms 824.507646012549
# Average charge per meter, dividing total charge over the distance of first/last dom with light 2.750604335010068
# Standard deviation 62.185161173239536
# Maximum corrected charge observed 325.0110142960266
# Mean corrected charge observed 75.59647684570214
# Ratio 4.299287848551428
# 127
# 17
# Total charge 1863.8573429410535
# distance between first and last doms 715.971716824282
# Average charge per meter, dividing total charge over the distance of first/last dom with light 2.603255546473622
# Standard deviation 93.0038928577961
# Maximum corrected charge observed 405.4126536282507
# Mean corrected charge observed 109.63866723182667
# Ratio 3.69771599622806
# 127
# 24
# Total charge 6391.264170031948
# distance between first and last doms 985.5955221890131
# Average charge per meter, dividing total charge over the distance of first/last dom with light 6.48467249104066
# Standard deviation 490.245792196651
# Maximum corrected charge observed 1795.5883511376094
# Mean corrected charge observed 266.30267375133116
# Ratio 6.742659868350773
# 128
# 49
# Total charge 5373.428173364955
# distance between first and last doms 1060.710827731218
# Average charge per meter, dividing total charge over the distance of first/last dom with light 5.06587472559163
# Standard deviation 81.23826469582981
# Maximum corrected charge observed 359.1084068905708
# Mean corrected charge observed 109.66179945642766
# Ratio 3.27469008050754
# 132
# 88
# Total charge 9603.10082526286
# distance between first and last doms 898.28648032932
# Average charge per meter, dividing total charge over the distance of first/last dom with light 10.690465720626536
# Standard deviation 70.3815677490142
# Maximum corrected charge observed 345.83321841209784
# Mean corrected charge observed 109.1261457416234
# Ratio 3.1691142032169153
# 128
# 94
# Total charge 10194.270781457797
# distance between first and last doms 429.25754674626467
# Average charge per meter, dividing total charge over the distance of first/last dom with light 23.7486116638589
# Standard deviation 83.5296099259362
# Maximum corrected charge observed 414.20181381028675
# Mean corrected charge observed 108.44968916444465
# Ratio 3.8192992253045874
# 133
# 137
# Total charge 11556.977645797411
# distance between first and last doms 989.1167382079971
# Average charge per meter, dividing total charge over the distance of first/last dom with light 11.684139191431967
# Standard deviation 59.991663751761976
# Maximum corrected charge observed 334.5222507566147
# Mean corrected charge observed 84.35750106421467
# Ratio 3.965530587516686
# 129
# 30
# Total charge 3320.733220590005
# distance between first and last doms 670.987501358856
# Average charge per meter, dividing total charge over the distance of first/last dom with light 4.9490239592615275
# Standard deviation 95.76894169838295
# Maximum corrected charge observed 531.4915743675974
# Mean corrected charge observed 110.69110735300018
# Ratio 4.801574282499866
# 128
# 21
# Total charge 3005.287527507836
# distance between first and last doms 270.5536206863672
# Average charge per meter, dividing total charge over the distance of first/last dom with light 11.107918348620599
# Standard deviation 122.3046075924416
# Maximum corrected charge observed 591.3281278906959
# Mean corrected charge observed 143.1089298813255
# Ratio 4.132014182350889
# 157
# 68
# Total charge 6929.613133561947
# distance between first and last doms 281.1269664411102
# Average charge per meter, dividing total charge over the distance of first/last dom with light 24.649407423579714
# Standard deviation 91.36439295321331
# Maximum corrected charge observed 559.5191131168281
# Mean corrected charge observed 101.90607549355803
# Ratio 5.490537344382356
# 129
# 84
# Total charge 100816.51909086997
# distance between first and last doms 680.992199292728
# Average charge per meter, dividing total charge over the distance of first/last dom with light 148.0435740608733
# Standard deviation 789.9972232114688
# Maximum corrected charge observed 4096.908972567016
# Mean corrected charge observed 1200.1966558436902
# Ratio 3.413531401391093
# 148
# 22
# Total charge 22581.68108548723
# distance between first and last doms 681.0408159727741
# Average charge per meter, dividing total charge over the distance of first/last dom with light 33.157603121381754
# Standard deviation 504.5614384784154
# Maximum corrected charge observed 2402.3960989534658
# Mean corrected charge observed 1026.4400493403286
# Ratio 2.3405128243947955
# 129
# 105
# Total charge 8448.964633599271
# distance between first and last doms 210.2932801788567
# Average charge per meter, dividing total charge over the distance of first/last dom with light 40.177054760919304
# Standard deviation 57.05454277128008
# Maximum corrected charge observed 326.9651346783608
# Mean corrected charge observed 80.46632984380258
# Ratio 4.063378251661907
# 149
# 12
# Total charge 1588.7936907298981
# distance between first and last doms 198.1528416128659
# Average charge per meter, dividing total charge over the distance of first/last dom with light 8.018021229460578
# Standard deviation 99.57198429488484
# Maximum corrected charge observed 336.4407766581338
# Mean corrected charge observed 132.3994742274915
# Ratio 2.541103570245712
# 129
# 65
# Total charge 9853.933107798317
# distance between first and last doms 113.06340618555657
# Average charge per meter, dividing total charge over the distance of first/last dom with light 87.15404426810132
# Standard deviation 103.85483551368233
# Maximum corrected charge observed 576.620823061622
# Mean corrected charge observed 151.59897088920488
# Ratio 3.8035932544887894
# 129
# 58
# Total charge 36845.85869719349
# distance between first and last doms 278.4949250843501
# Average charge per meter, dividing total charge over the distance of first/last dom with light 132.3035193048264
# Standard deviation 514.8912494908476
# Maximum corrected charge observed 2795.826764787151
# Mean corrected charge observed 635.2734258136809
# Ratio 4.400981768135754
# 147
# 101
# Total charge 9285.31745937075
# distance between first and last doms 495.9913057483422
# Average charge per meter, dividing total charge over the distance of first/last dom with light 18.720726254185525
# Standard deviation 53.11174383323576
# Maximum corrected charge observed 295.8536160701262
# Mean corrected charge observed 91.93383623139357
# Ratio 3.21811455061524
# 126
# 10
# Total charge 5285.025513688976
# distance between first and last doms 723.4179292701098
# Average charge per meter, dividing total charge over the distance of first/last dom with light 7.3056324703222195
# Standard deviation 769.1730194301781
# Maximum corrected charge observed 2605.5576103971725
# Mean corrected charge observed 528.5025513688977
# Ratio 4.9300757463675495
# 132
# 27
# Total charge 2982.87524276316
# distance between first and last doms 260.03161086789555
# Average charge per meter, dividing total charge over the distance of first/last dom with light 11.471202415765353
# Standard deviation 82.96994007827756
# Maximum corrected charge observed 297.2397305443838
# Mean corrected charge observed 110.47686084307999
# Ratio 2.6905157177354955
# 131
# 18
# Total charge 1745.3317390923348
# distance between first and last doms 255.0384406166599
# Average charge per meter, dividing total charge over the distance of first/last dom with light 6.843406565976017
# Standard deviation 90.19005174308906
# Maximum corrected charge observed 321.1305027752369
# Mean corrected charge observed 96.9628743940186
# Ratio 3.3118913272959514
# 179
# 68
# Total charge 14863.613030363762
# distance between first and last doms 96.43087923565287
# Average charge per meter, dividing total charge over the distance of first/last dom with light 154.13748322299148
# Standard deviation 131.372540946225
# Maximum corrected charge observed 604.2514428725361
# Mean corrected charge observed 218.58254456417296
# Ratio 2.7644084941793503
# 133
# 39
# Total charge 4288.67637108933
# distance between first and last doms 626.2365173121553
# Average charge per meter, dividing total charge over the distance of first/last dom with light 6.848333261523276
# Standard deviation 54.83356242056872
# Maximum corrected charge observed 235.95355682162347
# Mean corrected charge observed 109.96606079716231
# Ratio 2.145694363435016
# 129
# 95
# Total charge 14585.841365851275
# distance between first and last doms 921.5024985074028
# Average charge per meter, dividing total charge over the distance of first/last dom with light 15.828325359374054
# Standard deviation 120.30194469966645
# Maximum corrected charge observed 750.679113427092
# Mean corrected charge observed 153.53517227211867
# Ratio 4.88929736631697
# 146
# 51
# Total charge 5253.5269546634545
# distance between first and last doms 599.848476419437
# Average charge per meter, dividing total charge over the distance of first/last dom with light 8.758090019703555
# Standard deviation 85.08249312184041
# Maximum corrected charge observed 368.5859056216557
# Mean corrected charge observed 103.01033244438146
# Ratio 3.578144996480493
# 148
# 41
# Total charge 5593.080841790278
# distance between first and last doms 274.6009106092812
# Average charge per meter, dividing total charge over the distance of first/last dom with light 20.36803457563348
# Standard deviation 104.2251490660334
# Maximum corrected charge observed 508.23154454222714
# Mean corrected charge observed 136.41660589732385
# Ratio 3.725584148639175
# 129
# 32
# Total charge 3275.2262590882633
# distance between first and last doms 754.6207901602161
# Average charge per meter, dividing total charge over the distance of first/last dom with light 4.340227968530908
# Standard deviation 66.84564910124855
# Maximum corrected charge observed 313.3981895335944
# Mean corrected charge observed 102.35082059650823
# Ratio 3.0619997739840907
# 149
# 20
# Total charge 1706.080755291036
# distance between first and last doms 194.05691872852344
# Average charge per meter, dividing total charge over the distance of first/last dom with light 8.791651266388307
# Standard deviation 65.86927424657438
# Maximum corrected charge observed 306.2627207343603
# Mean corrected charge observed 85.3040377645518
# Ratio 3.5902488177602794
# 127
# 17
# Total charge 1229.6231219024646
# distance between first and last doms 536.1321564088997
# Average charge per meter, dividing total charge over the distance of first/last dom with light 2.29350750034969
# Standard deviation 60.39594146539811
# Maximum corrected charge observed 247.45214792436977
# Mean corrected charge observed 72.33077187661557
# Ratio 3.4211185848601553
# 129
# 46
# Total charge 55456.0419771393
# distance between first and last doms 325.7519323563735
# Average charge per meter, dividing total charge over the distance of first/last dom with light 170.2401013433444
# Standard deviation 746.9674870934448
# Maximum corrected charge observed 3463.9178924269095
# Mean corrected charge observed 1205.566129937811
# Ratio 2.873270745094336
# 129
# 40
# Total charge 4347.315157434619
# distance between first and last doms 781.0777861209436
# Average charge per meter, dividing total charge over the distance of first/last dom with light 5.565790289626125
# Standard deviation 92.98985632670019
# Maximum corrected charge observed 483.84767718280995
# Mean corrected charge observed 108.68287893586549
# Ratio 4.4519217922846135
# 129
# 63
# Total charge 36426.64446341717
# distance between first and last doms 299.28238968923523
# Average charge per meter, dividing total charge over the distance of first/last dom with light 121.71329058566184
# Standard deviation 583.7232331890903
# Maximum corrected charge observed 3551.6098488415855
# Mean corrected charge observed 578.2007057685265
# Ratio 6.142520777661272
# 145
# 29
# Total charge 31406.762525751077
# distance between first and last doms 952.6816950321942
# Average charge per meter, dividing total charge over the distance of first/last dom with light 32.966690437659494
# Standard deviation 571.8278329528754
# Maximum corrected charge observed 2435.2003765050017
# Mean corrected charge observed 1082.9918112327957
# Ratio 2.2485861400308784
# 128
# 31
# Total charge 3932.578514009635
# distance between first and last doms 783.6053408266333
# Average charge per meter, dividing total charge over the distance of first/last dom with light 5.018570330137257
# Standard deviation 118.32143986278537
# Maximum corrected charge observed 498.7601913449212
# Mean corrected charge observed 126.85737141966564
# Ratio 3.931661091218248
# 148
# 54
# Total charge 5679.345759213138
# distance between first and last doms 563.557520195879
# Average charge per meter, dividing total charge over the distance of first/last dom with light 10.077668304806108
# Standard deviation 112.94591566407529
# Maximum corrected charge observed 684.1353392017119
# Mean corrected charge observed 105.17306961505811
# Ratio 6.504852826923301
# 129
# 51
# Total charge 10112.510988744421
# distance between first and last doms 119.96205026653503
# Average charge per meter, dividing total charge over the distance of first/last dom with light 84.2975838298542
# Standard deviation 223.06967948981625
# Maximum corrected charge observed 1257.3387874725543
# Mean corrected charge observed 198.2845291910671
# Ratio 6.341083656914967
# 127
# 101
# Total charge 14921.46547667268
# distance between first and last doms 1296.7753318301097
# Average charge per meter, dividing total charge over the distance of first/last dom with light 11.506592630517078
# Standard deviation 114.11077113146288
# Maximum corrected charge observed 791.5577545403132
# Mean corrected charge observed 147.73728194725425
# Ratio 5.357874086399656
# 126
# 18
# Total charge 1199.5686954365826
# distance between first and last doms 606.465266345326
# Average charge per meter, dividing total charge over the distance of first/last dom with light 1.9779676792793257
# Standard deviation 44.13155846576749
# Maximum corrected charge observed 194.79059182906653
# Mean corrected charge observed 66.64270530203237
# Ratio 2.922909430916006
# 129
# 80
# Total charge 10245.759201560884
# distance between first and last doms 755.3787332395941
# Average charge per meter, dividing total charge over the distance of first/last dom with light 13.563737964424652
# Standard deviation 96.42202723258266
# Maximum corrected charge observed 611.9750921097998
# Mean corrected charge observed 128.07199001951105
# Ratio 4.778367947718848
# 129
# 51
# Total charge 12405.564664646809
# distance between first and last doms 1075.2936775692096
# Average charge per meter, dividing total charge over the distance of first/last dom with light 11.53690840319141
# Standard deviation 512.0967424673779
# Maximum corrected charge observed 2802.6204005512154
# Mean corrected charge observed 243.24636597346682
# Ratio 11.521735954143395
# 128
# 34
# Total charge 4580.5545680390205
# distance between first and last doms 460.25681025866845
# Average charge per meter, dividing total charge over the distance of first/last dom with light 9.952171192132296
# Standard deviation 119.95186590186204
# Maximum corrected charge observed 548.2071100801924
# Mean corrected charge observed 134.72219317761824
# Ratio 4.069167055181725
# 128
# 54
# Total charge 47239.80273901905
# distance between first and last doms 107.5969443448273
# Average charge per meter, dividing total charge over the distance of first/last dom with light 439.0440920666358
# Standard deviation 593.8779750200498
# Maximum corrected charge observed 3899.2453400922973
# Mean corrected charge observed 874.811161833686
# Ratio 4.45724232864052
# 129
# 96
# Total charge 14668.30989337637
# distance between first and last doms 333.87289272737706
# Average charge per meter, dividing total charge over the distance of first/last dom with light 43.93381497237554
# Standard deviation 123.4138598374308
# Maximum corrected charge observed 748.4227276537258
# Mean corrected charge observed 152.79489472267053
# Ratio 4.898218157171717
# 128
# 27
# Total charge 3692.0572262792043
# distance between first and last doms 865.2835127142915
# Average charge per meter, dividing total charge over the distance of first/last dom with light 4.266875737291769
# Standard deviation 98.19694768188462
# Maximum corrected charge observed 402.4583621113438
# Mean corrected charge observed 136.74286023256312
# Ratio 2.943176421985539
# 129
# 14
# Total charge 1177.3982346209211
# distance between first and last doms 228.45958731968733
# Average charge per meter, dividing total charge over the distance of first/last dom with light 5.1536389802427855
# Standard deviation 45.72131756095682
# Maximum corrected charge observed 203.05771694585317
# Mean corrected charge observed 84.09987390149436
# Ratio 2.4144830131813677
# 132
# 33
# Total charge 4381.537901835165
# distance between first and last doms 269.4348993134909
# Average charge per meter, dividing total charge over the distance of first/last dom with light 16.26195386343471
# Standard deviation 84.49482467793705
# Maximum corrected charge observed 333.41637554950984
# Mean corrected charge observed 132.7738758131868
# Ratio 2.5111594694925343
# 131
# 19
# Total charge 2400.5272826846035
# distance between first and last doms 372.92856172125744
# Average charge per meter, dividing total charge over the distance of first/last dom with light 6.436962810262999
# Standard deviation 64.23004249229166
# Maximum corrected charge observed 284.75741098358014
# Mean corrected charge observed 126.3435411939265
# Ratio 2.253834333695792
# 132
# 41
# Total charge 5829.340840736269
# distance between first and last doms 737.4934935722455
# Average charge per meter, dividing total charge over the distance of first/last dom with light 7.904260704050837
# Standard deviation 87.41583121099748
# Maximum corrected charge observed 344.3603902307628
# Mean corrected charge observed 142.17904489600656
# Ratio 2.4220192960406854
# 132
# 40
# Total charge 3955.1392752205584
# distance between first and last doms 262.3061760065154
# Average charge per meter, dividing total charge over the distance of first/last dom with light 15.078330733327137
# Standard deviation 91.8335389691649
# Maximum corrected charge observed 448.0661258917977
# Mean corrected charge observed 98.87848188051396
# Ratio 4.5314826580089145
# 129
# 82
# Total charge 8167.722156517232
# distance between first and last doms 257.7160588651039
# Average charge per meter, dividing total charge over the distance of first/last dom with light 31.692717141823344
# Standard deviation 66.0313100887213
# Maximum corrected charge observed 397.9844832282224
# Mean corrected charge observed 99.60636776240527
# Ratio 3.9955726944842467
# 129
# 69
# Total charge 8541.596851487506
# distance between first and last doms 264.74476753435715
# Average charge per meter, dividing total charge over the distance of first/last dom with light 32.26351527562872
# Standard deviation 121.80778564356332
# Maximum corrected charge observed 926.3669336905542
# Mean corrected charge observed 123.79125871721023
# Ratio 7.48329844360622
# 128
# 24
# Total charge 3009.4912653709544
# distance between first and last doms 193.8808864294741
# Average charge per meter, dividing total charge over the distance of first/last dom with light 15.522372116168778
# Standard deviation 96.72700121744742
# Maximum corrected charge observed 388.97387296255613
# Mean corrected charge observed 125.39546939045643
# Ratio 3.1019770877954866
# 128
# 33
# Total charge 3248.540466550583
# distance between first and last doms 824.222575205795
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.9413388619445118
# Standard deviation 68.68244771197033
# Maximum corrected charge observed 266.37348982734954
# Mean corrected charge observed 98.44062019850251
# Ratio 2.7059306340229825
# 127
# 18
# Total charge 1752.5528800195439
# distance between first and last doms 250.78643165394703
# Average charge per meter, dividing total charge over the distance of first/last dom with light 6.988228463802384
# Standard deviation 58.883212607829215
# Maximum corrected charge observed 244.82345396802836
# Mean corrected charge observed 97.36404888997465
# Ratio 2.5145159507970836
# 216
# 64
# Total charge 16334.645678633027
# distance between first and last doms 471.10230282430945
# Average charge per meter, dividing total charge over the distance of first/last dom with light 34.673245239314376
# Standard deviation 390.23222914424906
# Maximum corrected charge observed 1935.058291679866
# Mean corrected charge observed 255.22883872864105
# Ratio 7.581660055810611
# 127
# 35
# Total charge 3532.307909999635
# distance between first and last doms 361.985142287699
# Average charge per meter, dividing total charge over the distance of first/last dom with light 9.758157165445821
# Standard deviation 82.39582468025172
# Maximum corrected charge observed 336.20144782906283
# Mean corrected charge observed 100.9230831428467
# Ratio 3.3312641405653722
# 127
# 28
# Total charge 3133.666640563312
# distance between first and last doms 253.27861640533078
# Average charge per meter, dividing total charge over the distance of first/last dom with light 12.372409029384437
# Standard deviation 74.70380260345124
# Maximum corrected charge observed 397.84277022605664
# Mean corrected charge observed 111.91666573440399
# Ratio 3.55481257072294
# 129
# 75
# Total charge 8913.345860805894
# distance between first and last doms 348.8293126589269
# Average charge per meter, dividing total charge over the distance of first/last dom with light 25.552169893248198
# Standard deviation 69.54962569306754
# Maximum corrected charge observed 318.75979339769395
# Mean corrected charge observed 118.84461147741192
# Ratio 2.682156047590586
# 132
# 85
# Total charge 9635.885861224848
# distance between first and last doms 705.0772088704814
# Average charge per meter, dividing total charge over the distance of first/last dom with light 13.66642651329112
# Standard deviation 75.22123358051522
# Maximum corrected charge observed 351.0816149536049
# Mean corrected charge observed 113.3633630732335
# Ratio 3.096958359702189
# 127
# 44
# Total charge 36525.37160388456
# distance between first and last doms 518.1951246874557
# Average charge per meter, dividing total charge over the distance of first/last dom with light 70.48574921640662
# Standard deviation 587.9825568794253
# Maximum corrected charge observed 2501.1281130339307
# Mean corrected charge observed 830.1220819064673
# Ratio 3.0129641983379276
# 128
# 34
# Total charge 3750.560289644826
# distance between first and last doms 415.3413214249384
# Average charge per meter, dividing total charge over the distance of first/last dom with light 9.030067792863795
# Standard deviation 62.62238576175075
# Maximum corrected charge observed 254.87372391587425
# Mean corrected charge observed 110.31059675425958
# Ratio 2.310509882234251
# 132
# 67
# Total charge 6545.925986716611
# distance between first and last doms 298.04545264995096
# Average charge per meter, dividing total charge over the distance of first/last dom with light 21.96284468867466
# Standard deviation 61.323119134946936
# Maximum corrected charge observed 273.6658161104931
# Mean corrected charge observed 97.70038786144195
# Ratio 2.8010719517163447
# 133
# 40
# Total charge 11462.38264342809
# distance between first and last doms 357.59294560722117
# Average charge per meter, dividing total charge over the distance of first/last dom with light 32.054275075152994
# Standard deviation 230.9030114247523
# Maximum corrected charge observed 874.8158048955553
# Mean corrected charge observed 286.5595660857023
# Ratio 3.052823595614747
# 129
# 72
# Total charge 9249.769248619183
# distance between first and last doms 497.4750592364351
# Average charge per meter, dividing total charge over the distance of first/last dom with light 18.593433131736244
# Standard deviation 116.74960920797784
# Maximum corrected charge observed 865.0655987890674
# Mean corrected charge observed 128.4690173419331
# Ratio 6.733651558076521
# 129
# 45
# Total charge 5928.76822951449
# distance between first and last doms 277.5528594959637
# Average charge per meter, dividing total charge over the distance of first/last dom with light 21.36086164012556
# Standard deviation 111.43057951043725
# Maximum corrected charge observed 549.0674757885022
# Mean corrected charge observed 131.75040510032198
# Ratio 4.167482258368861
# 125
# 6
# Total charge 11055.580652549255
# distance between first and last doms 1001.4453715071874
# Average charge per meter, dividing total charge over the distance of first/last dom with light 11.039624294144446
# Standard deviation 3550.0349535132586
# Maximum corrected charge observed 9725.570038859276
# Mean corrected charge observed 1842.596775424876
# Ratio 5.278186833153825
# 129
# 38
# Total charge 31911.005793271797
# distance between first and last doms 840.1892073680849
# Average charge per meter, dividing total charge over the distance of first/last dom with light 37.98073756890293
# Standard deviation 504.0710703442623
# Maximum corrected charge observed 2448.2938778050984
# Mean corrected charge observed 839.7633103492578
# Ratio 2.9154570670476807
# 129
# 79
# Total charge 50968.68411479261
# distance between first and last doms 918.2312320769408
# Average charge per meter, dividing total charge over the distance of first/last dom with light 55.50746079449606
# Standard deviation 323.2653262485021
# Maximum corrected charge observed 1746.9299379743209
# Mean corrected charge observed 645.1732166429445
# Ratio 2.707691350028743
# 129
# 38
# Total charge 5142.234985512636
# distance between first and last doms 262.11981047960086
# Average charge per meter, dividing total charge over the distance of first/last dom with light 19.61787999199253
# Standard deviation 107.24905056955862
# Maximum corrected charge observed 372.6027475527372
# Mean corrected charge observed 135.3219733029641
# Ratio 2.7534534004949784
# 128
# 16
# Total charge 14697.030552771255
# distance between first and last doms 577.8664903690049
# Average charge per meter, dividing total charge over the distance of first/last dom with light 25.433263215152444
# Standard deviation 1010.6646162069966
# Maximum corrected charge observed 4589.668695921909
# Mean corrected charge observed 918.5644095482035
# Ratio 4.996567086873462
# 128
# 38
# Total charge 4254.534058623361
# distance between first and last doms 916.5884516313613
# Average charge per meter, dividing total charge over the distance of first/last dom with light 4.641705937982375
# Standard deviation 67.39629738492435
# Maximum corrected charge observed 289.628600923821
# Mean corrected charge observed 111.96142259535159
# Ratio 2.5868606722745033
# 128
# 20
# Total charge 4765.601161906153
# distance between first and last doms 697.182388694946
# Average charge per meter, dividing total charge over the distance of first/last dom with light 6.835515697444495
# Standard deviation 546.9879451327355
# Maximum corrected charge observed 2531.47051580274
# Mean corrected charge observed 238.28005809530765
# Ratio 10.623929404911419
# 129
# 91
# Total charge 9843.976278867463
# distance between first and last doms 765.1899109223482
# Average charge per meter, dividing total charge over the distance of first/last dom with light 12.864749179718908
# Standard deviation 75.2498758571862
# Maximum corrected charge observed 332.98568596084715
# Mean corrected charge observed 108.17556350403805
# Ratio 3.0781969159644564
# 148
# 16
# Total charge 790.6898501421103
# distance between first and last doms 494.7465025315396
# Average charge per meter, dividing total charge over the distance of first/last dom with light 1.5981716820559124
# Standard deviation 30.715737880042028
# Maximum corrected charge observed 126.5743379221996
# Mean corrected charge observed 49.4181156338819
# Ratio 2.5612943006555695
# 129
# 103
# Total charge 8389.540756996716
# distance between first and last doms 312.30952012559993
# Average charge per meter, dividing total charge over the distance of first/last dom with light 26.862904318839647
# Standard deviation 57.92530601406764
# Maximum corrected charge observed 289.5790674903669
# Mean corrected charge observed 81.45185200967686
# Ratio 3.555217718756887
# 129
# 25
# Total charge 1785.4010742527907
# distance between first and last doms 120.68182679290416
# Average charge per meter, dividing total charge over the distance of first/last dom with light 14.794282798822934
# Standard deviation 48.98141799590134
# Maximum corrected charge observed 246.22591574293733
# Mean corrected charge observed 71.41604297011163
# Ratio 3.447767553377124
# 149
# 32
# Total charge 3658.384240735078
# distance between first and last doms 131.6615494029196
# Average charge per meter, dividing total charge over the distance of first/last dom with light 27.786276686896965
# Standard deviation 106.56162669283925
# Maximum corrected charge observed 523.5151638477417
# Mean corrected charge observed 114.32450752297119
# Ratio 4.579203315112046
# 132
# 50
# Total charge 5296.844745901703
# distance between first and last doms 556.5567254717106
# Average charge per meter, dividing total charge over the distance of first/last dom with light 9.517169595628108
# Standard deviation 86.28252290750972
# Maximum corrected charge observed 357.5994627560744
# Mean corrected charge observed 105.93689491803407
# Ratio 3.3755894302240756
# 129
# 37
# Total charge 3208.8452973444796
# distance between first and last doms 155.3423807874497
# Average charge per meter, dividing total charge over the distance of first/last dom with light 20.656599191273152
# Standard deviation 79.43210384165418
# Maximum corrected charge observed 368.58837263533536
# Mean corrected charge observed 86.72554857687783
# Ratio 4.250055245353685
# 172
# 25
# Total charge 3197.8178023873725
# distance between first and last doms 221.51329982707716
# Average charge per meter, dividing total charge over the distance of first/last dom with light 14.436233873468217
# Standard deviation 101.10144446581647
# Maximum corrected charge observed 419.3913887818656
# Mean corrected charge observed 127.9127120954949
# Ratio 3.2787311121099796
# 129
# 30
# Total charge 2750.7449751570284
# distance between first and last doms 1010.7030609519225
# Average charge per meter, dividing total charge over the distance of first/last dom with light 2.7216153600705053
# Standard deviation 66.28349200245204
# Maximum corrected charge observed 229.8333589200922
# Mean corrected charge observed 91.69149917190094
# Ratio 2.5065939699514166
# 128
# 47
# Total charge 8320.597471050038
# distance between first and last doms 892.6110879511923
# Average charge per meter, dividing total charge over the distance of first/last dom with light 9.32163803851942
# Standard deviation 116.0303180518894
# Maximum corrected charge observed 600.7648936949065
# Mean corrected charge observed 177.0339887457455
# Ratio 3.3935002987348337
# 127
# 24
# Total charge 2267.4688223711046
# distance between first and last doms 1326.9086099281858
# Average charge per meter, dividing total charge over the distance of first/last dom with light 1.7088357143856525
# Standard deviation 68.2959126549167
# Maximum corrected charge observed 309.5136082102704
# Mean corrected charge observed 94.47786759879602
# Ratio 3.276043544130696
# 132
# 22
# Total charge 2431.359942233773
# distance between first and last doms 212.55750529774926
# Average charge per meter, dividing total charge over the distance of first/last dom with light 11.438598410476914
# Standard deviation 84.9441519864057
# Maximum corrected charge observed 366.85023969242775
# Mean corrected charge observed 110.51636101062604
# Ratio 3.3194201866378448
# 129
# 79
# Total charge 8824.739095248748
# distance between first and last doms 497.44023369820934
# Average charge per meter, dividing total charge over the distance of first/last dom with light 17.740300235952777
# Standard deviation 74.82642441533022
# Maximum corrected charge observed 402.6559087622343
# Mean corrected charge observed 111.70555816770566
# Ratio 3.6046183857540854
# 126
# 21
# Total charge 2364.337287158292
# distance between first and last doms 594.9334041320111
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.9741209196477794
# Standard deviation 91.88467193806075
# Maximum corrected charge observed 385.5795908559351
# Mean corrected charge observed 112.58748986468056
# Ratio 3.4247107855354537
# 131
# 13
# Total charge 1507.6584100977075
# distance between first and last doms 333.02141555308464
# Average charge per meter, dividing total charge over the distance of first/last dom with light 4.527211583656793
# Standard deviation 44.277038500016765
# Maximum corrected charge observed 176.72160069636357
# Mean corrected charge observed 115.97372385366981
# Ratio 1.5238072455045297
# 129
# 34
# Total charge 3728.871608024995
# distance between first and last doms 908.3170379576201
# Average charge per meter, dividing total charge over the distance of first/last dom with light 4.105253399638393
# Standard deviation 114.74242393958646
# Maximum corrected charge observed 613.5264006308664
# Mean corrected charge observed 109.67269435367632
# Ratio 5.594158183552463
# 147
# 14
# Total charge 881.90600057961
# distance between first and last doms 211.38543859746858
# Average charge per meter, dividing total charge over the distance of first/last dom with light 4.172028151186811
# Standard deviation 45.33626160457375
# Maximum corrected charge observed 195.6660976478979
# Mean corrected charge observed 62.99328575568643
# Ratio 3.1061421118239583
# 127
# 56
# Total charge 30930.931998203992
# distance between first and last doms 614.9323077808833
# Average charge per meter, dividing total charge over the distance of first/last dom with light 50.299734794915835
# Standard deviation 843.0255495460349
# Maximum corrected charge observed 5329.267035102428
# Mean corrected charge observed 552.3380713964999
# Ratio 9.648560023444002
# 127
# 18
# Total charge 1745.7435509376105
# distance between first and last doms 513.6472008868963
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.398721044178373
# Standard deviation 75.02418989107834
# Maximum corrected charge observed 247.53367024870576
# Mean corrected charge observed 96.98575282986725
# Ratio 2.5522683799024604
# 130
# 23
# Total charge 18575.541364752673
# distance between first and last doms 335.63044980873735
# Average charge per meter, dividing total charge over the distance of first/last dom with light 55.3452208383898
# Standard deviation 878.1737781720508
# Maximum corrected charge observed 4237.146436234495
# Mean corrected charge observed 807.6322332501162
# Ratio 5.246381040517845
# 129
# 72
# Total charge 8412.22289261276
# distance between first and last doms 231.91028524152603
# Average charge per meter, dividing total charge over the distance of first/last dom with light 36.2736084941284
# Standard deviation 81.96004393665731
# Maximum corrected charge observed 399.41332919947376
# Mean corrected charge observed 116.8364290640661
# Ratio 3.4185684413588113
# 129
# 89
# Total charge 8997.635972696104
# distance between first and last doms 391.14393627123303
# Average charge per meter, dividing total charge over the distance of first/last dom with light 23.003388620747593
# Standard deviation 66.63246532057707
# Maximum corrected charge observed 338.47096211461616
# Mean corrected charge observed 101.09703340107981
# Ratio 3.3479811496723992
# 132
# 14
# Total charge 1023.6978421455738
# distance between first and last doms 291.3515027732192
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.513617854727164
# Standard deviation 40.862056894487054
# Maximum corrected charge observed 151.64075909713506
# Mean corrected charge observed 73.12127443896955
# Ratio 2.073825439458137
# 130
# 23
# Total charge 1787.1219651533302
# distance between first and last doms 430.4612411444899
# Average charge per meter, dividing total charge over the distance of first/last dom with light 4.151644316226509
# Standard deviation 64.04526237611206
# Maximum corrected charge observed 304.05448177322603
# Mean corrected charge observed 77.70095500666653
# Ratio 3.913136997442811
# 128
# 30
# Total charge 3079.0134148056363
# distance between first and last doms 1020.6385104674077
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.0167521441020124
# Standard deviation 78.97961320006253
# Maximum corrected charge observed 343.59953713002943
# Mean corrected charge observed 102.63378049352121
# Ratio 3.347821111897162
# 129
# 44
# Total charge 5598.258525423865
# distance between first and last doms 127.08963193579632
# Average charge per meter, dividing total charge over the distance of first/last dom with light 44.04968713932555
# Standard deviation 87.19041108625137
# Maximum corrected charge observed 395.3275502580625
# Mean corrected charge observed 127.23314830508784
# Ratio 3.1071112797595846
# 129
# 39
# Total charge 4816.920586671444
# distance between first and last doms 1024.0937644935711
# Average charge per meter, dividing total charge over the distance of first/last dom with light 4.703593317017685
# Standard deviation 79.13695714853418
# Maximum corrected charge observed 341.46822651328114
# Mean corrected charge observed 123.51078427362677
# Ratio 2.764683493198373
# 127
# 36
# Total charge 5223.930626433092
# distance between first and last doms 433.94103250091933
# Average charge per meter, dividing total charge over the distance of first/last dom with light 12.03834215982335
# Standard deviation 102.56625981145197
# Maximum corrected charge observed 397.1463881783093
# Mean corrected charge observed 145.1091840675859
# Ratio 2.7368797552698996
# 132
# 44
# Total charge 5735.900617275349
# distance between first and last doms 385.9076204911589
# Average charge per meter, dividing total charge over the distance of first/last dom with light 14.86340334501572
# Standard deviation 89.96797838301498
# Maximum corrected charge observed 499.7822267024684
# Mean corrected charge observed 130.36137766534884
# Ratio 3.8338213023911205
# 126
# 12
# Total charge 1130.767273367926
# distance between first and last doms 322.8227780823492
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.502749341558164
# Standard deviation 76.29050003963104
# Maximum corrected charge observed 237.34017858914757
# Mean corrected charge observed 94.23060611399383
# Ratio 2.5187164593001707
# 133
# 14
# Total charge 690.2841788906205
# distance between first and last doms 372.10671245493864
# Average charge per meter, dividing total charge over the distance of first/last dom with light 1.8550704832399725
# Standard deviation 26.59618797368824
# Maximum corrected charge observed 103.98534734918944
# Mean corrected charge observed 49.306012777901465
# Ratio 2.1089790370515376
# 129
# 42
# Total charge 7108.355600846056
# distance between first and last doms 291.8880019856919
# Average charge per meter, dividing total charge over the distance of first/last dom with light 24.353024284960167
# Standard deviation 202.6935062880764
# Maximum corrected charge observed 1333.8101762133551
# Mean corrected charge observed 169.2465619249061
# Ratio 7.8808701402463965
# 133
# 56
# Total charge 22263.543198632433
# distance between first and last doms 662.0300551356314
# Average charge per meter, dividing total charge over the distance of first/last dom with light 33.629203124428024
# Standard deviation 452.9269494333526
# Maximum corrected charge observed 2636.434838414585
# Mean corrected charge observed 397.5632714041506
# Ratio 6.631484918370305
# 150
# 101
# Total charge 11134.90785200671
# distance between first and last doms 320.4116387085565
# Average charge per meter, dividing total charge over the distance of first/last dom with light 34.751883223989005
# Standard deviation 81.16756389693039
# Maximum corrected charge observed 530.759515094157
# Mean corrected charge observed 110.24661239610604
# Ratio 4.814293188322072
# 148
# 22
# Total charge 2012.0175684426029
# distance between first and last doms 336.1003242736113
# Average charge per meter, dividing total charge over the distance of first/last dom with light 5.986360092900913
# Standard deviation 81.32340431426809
# Maximum corrected charge observed 381.63752646624863
# Mean corrected charge observed 91.45534402011832
# Ratio 4.172938504088904
# 126
# 24
# Total charge 2285.9372706430586
# distance between first and last doms 649.1657558091864
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.5213460509691137
# Standard deviation 58.56181088781967
# Maximum corrected charge observed 230.8203870161755
# Mean corrected charge observed 95.2473862767941
# Ratio 2.423377648866908
# 128
# 26
# Total charge 2466.064446943763
# distance between first and last doms 640.9332591934955
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.847615038805884
# Standard deviation 66.3971261456701
# Maximum corrected charge observed 273.6359053093746
# Mean corrected charge observed 94.84863257476012
# Ratio 2.8849747000168247
# 129
# 21
# Total charge 1626.0736514547777
# distance between first and last doms 591.746966538358
# Average charge per meter, dividing total charge over the distance of first/last dom with light 2.747920552879375
# Standard deviation 65.16143331880669
# Maximum corrected charge observed 252.52466188042342
# Mean corrected charge observed 77.43207864070371
# Ratio 3.261240900585598
# 128
# 42
# Total charge 5924.478961514288
# distance between first and last doms 435.93361983005514
# Average charge per meter, dividing total charge over the distance of first/last dom with light 13.590323599780842
# Standard deviation 98.15598654499024
# Maximum corrected charge observed 407.77855871095613
# Mean corrected charge observed 141.05902289319732
# Ratio 2.890836405549932
# 127
# 17
# Total charge 1781.6309570780318
# distance between first and last doms 250.77119371684145
# Average charge per meter, dividing total charge over the distance of first/last dom with light 7.104607712996582
# Standard deviation 63.13450328850844
# Maximum corrected charge observed 261.6688695990643
# Mean corrected charge observed 104.80182100459011
# Ratio 2.4967969744304703
# 132
# 35
# Total charge 3367.5931807284583
# distance between first and last doms 938.9718183970227
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.5864688532159423
# Standard deviation 84.27370133969585
# Maximum corrected charge observed 402.72091594118154
# Mean corrected charge observed 96.21694802081309
# Ratio 4.185550718716076
# 128
# 29
# Total charge 3335.4521070404307
# distance between first and last doms 248.60488908817035
# Average charge per meter, dividing total charge over the distance of first/last dom with light 13.4166794517765
# Standard deviation 80.42926227436384
# Maximum corrected charge observed 377.4987217470189
# Mean corrected charge observed 115.01558989794589
# Ratio 3.2821526375857055
# 172
# 31
# Total charge 2583.374342071214
# distance between first and last doms 430.8122923249577
# Average charge per meter, dividing total charge over the distance of first/last dom with light 5.99651957034364
# Standard deviation 61.065049533577216
# Maximum corrected charge observed 260.6944737405558
# Mean corrected charge observed 83.33465619584561
# Ratio 3.12828402541069
# 129
# 32
# Total charge 3115.2982720894483
# distance between first and last doms 380.0996030306263
# Average charge per meter, dividing total charge over the distance of first/last dom with light 8.196005066173234
# Standard deviation 73.07756554848537
# Maximum corrected charge observed 311.2252298691254
# Mean corrected charge observed 97.35307100279526
# Ratio 3.1968712097452925
# 147
# 23
# Total charge 4057.167780417638
# distance between first and last doms 311.88492799181506
# Average charge per meter, dividing total charge over the distance of first/last dom with light 13.00854070294834
# Standard deviation 152.05318239544872
# Maximum corrected charge observed 736.6974342733736
# Mean corrected charge observed 176.39859914859295
# Ratio 4.176322475513547
# 129
# 36
# Total charge 3797.9936634596343
# distance between first and last doms 665.0276335783213
# Average charge per meter, dividing total charge over the distance of first/last dom with light 5.711031349214361
# Standard deviation 71.8940943081709
# Maximum corrected charge observed 260.3437132451917
# Mean corrected charge observed 105.49982398498985
# Ratio 2.4677170388666476
# 129
# 48
# Total charge 7226.186389037105
# distance between first and last doms 157.99220949850942
# Average charge per meter, dividing total charge over the distance of first/last dom with light 45.73761207577314
# Standard deviation 96.37319757966135
# Maximum corrected charge observed 590.7804940754409
# Mean corrected charge observed 150.54554977160635
# Ratio 3.9242640846688452
# 129
# 33
# Total charge 4674.337995070011
# distance between first and last doms 377.3764067732549
# Average charge per meter, dividing total charge over the distance of first/last dom with light 12.386407605705378
# Standard deviation 104.35521468533273
# Maximum corrected charge observed 510.69214167128484
# Mean corrected charge observed 141.64660591121245
# Ratio 3.6053962492500466
# 129
# 39
# Total charge 4100.520304316232
# distance between first and last doms 120.97934817095839
# Average charge per meter, dividing total charge over the distance of first/last dom with light 33.894382523219605
# Standard deviation 67.93918213192966
# Maximum corrected charge observed 319.13185263908264
# Mean corrected charge observed 105.14154626451877
# Ratio 3.035259266933355
# 147
# 44
# Total charge 26881.832863498596
# distance between first and last doms 265.69917542651143
# Average charge per meter, dividing total charge over the distance of first/last dom with light 101.17394162156037
# Standard deviation 1245.915244571025
# Maximum corrected charge observed 7565.538361955351
# Mean corrected charge observed 610.9507468976954
# Ratio 12.383221397750763
# 129
# 91
# Total charge 13283.380458119538
# distance between first and last doms 425.5490288092911
# Average charge per meter, dividing total charge over the distance of first/last dom with light 31.214688693538196
# Standard deviation 95.88833736040536
# Maximum corrected charge observed 570.9353569424431
# Mean corrected charge observed 145.97121382548943
# Ratio 3.9112873146687956
# 154
# 115
# Total charge 22374.85932715216
# distance between first and last doms 73.07877352784388
# Average charge per meter, dividing total charge over the distance of first/last dom with light 306.1745325901929
# Standard deviation 133.71647538356484
# Maximum corrected charge observed 740.9996639164272
# Mean corrected charge observed 194.5639941491492
# Ratio 3.8085138370894582
# 129
# 35
# Total charge 4483.464817732944
# distance between first and last doms 162.02486345722895
# Average charge per meter, dividing total charge over the distance of first/last dom with light 27.6714617871996
# Standard deviation 161.02052183540223
# Maximum corrected charge observed 905.9696169462367
# Mean corrected charge observed 128.0989947923698
# Ratio 7.07241784695254
# 133
# 61
# Total charge 6974.257266254887
# distance between first and last doms 594.4879004242497
# Average charge per meter, dividing total charge over the distance of first/last dom with light 11.731537784499544
# ...
# Ratio 1.9876620574098591
# 133
# 43
# Total charge 6291.360366123847
# distance between first and last doms 738.7853895338512
# Average charge per meter, dividing total charge over the distance of first/last dom with light 8.515815898976404
# Standard deviation 113.39284242969977
# Maximum corrected charge observed 556.9736719626255
# Mean corrected charge observed 146.31070618892667
# Ratio 3.8067868474602395
# 155
# 259
# Total charge 50433.72396917055
# distance between first and last doms 321.3961981283829
# Average charge per meter, dividing total charge over the distance of first/last dom with light 156.92072358934567
# Standard deviation 160.10453029578485
# Maximum corrected charge observed 1234.4133195016414
# Mean corrected charge observed 194.72480296977045
# Ratio 6.339271118396122
# 129
# 32
# Total charge 4229.174320890742
# distance between first and last doms 223.1375898228896
# Average charge per meter, dividing total charge over the distance of first/last dom with light 18.95321323604666
# Standard deviation 85.67974568659301
# Maximum corrected charge observed 314.9265661071913
# Mean corrected charge observed 132.16169752783568
# Ratio 2.382888325423196
# 132
# 51
# Total charge 6005.730131863021
# distance between first and last doms 732.7673192171729
# Average charge per meter, dividing total charge over the distance of first/last dom with light 8.195957945121021
# Standard deviation 88.4083145328634
# Maximum corrected charge observed 421.1776202610607
# Mean corrected charge observed 117.75941435025531
# Ratio 3.5765940463013823
# 171
# 18
# Total charge 1793.9934687602126
# distance between first and last doms 632.7635692713271
# Average charge per meter, dividing total charge over the distance of first/last dom with light 2.8351718649449515
# Standard deviation 67.44597100590441
# Maximum corrected charge observed 241.2469273885292
# Mean corrected charge observed 99.66630382001182
# Ratio 2.4205465452415993
# 129
# 53
# Total charge 7197.730112360003
# distance between first and last doms 1169.9496659100707
# Average charge per meter, dividing total charge over the distance of first/last dom with light 6.152170748953624
# Standard deviation 109.70309186457041
# Maximum corrected charge observed 642.3656920977452
# Mean corrected charge observed 135.8062285350944
# Ratio 4.730016428751264
# 129
# 16
# Total charge 1319.8513280177199
# distance between first and last doms 372.21621314980723
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.5459264840957223
# Standard deviation 58.12581984217146
# Maximum corrected charge observed 274.39645841789746
# Mean corrected charge observed 82.49070800110749
# Ratio 3.3263923303242047
# 129
# 40
# Total charge 5138.531518482499
# distance between first and last doms 160.9722223811726
# Average charge per meter, dividing total charge over the distance of first/last dom with light 31.921852369750876
# Standard deviation 126.62172995238913
# Maximum corrected charge observed 630.8590358488622
# Mean corrected charge observed 128.46328796206248
# Ratio 4.910811842486596
# 171
# 43
# Total charge 3882.459738286101
# distance between first and last doms 215.28502403905543
# Average charge per meter, dividing total charge over the distance of first/last dom with light 18.034044660634517
# Standard deviation 70.0581571930459
# Maximum corrected charge observed 327.3574653358053
# Mean corrected charge observed 90.28976135549073
# Ratio 3.625632191527527
# 129
# 181
# Total charge 21569.322214890475
# distance between first and last doms 909.3311674910909
# Average charge per meter, dividing total charge over the distance of first/last dom with light 23.719985618002912
# Standard deviation 71.94237405822334
# Maximum corrected charge observed 454.9999515619835
# Mean corrected charge observed 119.16752604911865
# Ratio 3.8181538767066536
# 128
# 30
# Total charge 2837.934464872807
# distance between first and last doms 316.27852474546495
# Average charge per meter, dividing total charge over the distance of first/last dom with light 8.972896491017604
# Standard deviation 53.3325462538222
# Maximum corrected charge observed 240.84071241378643
# Mean corrected charge observed 94.59781549576023
# Ratio 2.5459437001965513
# 128
# 34
# Total charge 3928.496371011139
# distance between first and last doms 71.50597147506865
# Average charge per meter, dividing total charge over the distance of first/last dom with light 54.93941680634118
# Standard deviation 90.7942391596795
# Maximum corrected charge observed 492.66180014695044
# Mean corrected charge observed 115.54401091209233
# Ratio 4.263845406247626
# 129
# 191
# Total charge 26925.5859477872
# distance between first and last doms 792.271970563377
# Average charge per meter, dividing total charge over the distance of first/last dom with light 33.98528150458318
# Standard deviation 80.29470381247306
# Maximum corrected charge observed 373.3294626730724
# Mean corrected charge observed 140.97165417689632
# Ratio 2.6482590762863936
# 128
# 56
# Total charge 13382.486875713585
# distance between first and last doms 95.3577914215601
# Average charge per meter, dividing total charge over the distance of first/last dom with light 140.33973182696687
# Standard deviation 202.28846378421406
# Maximum corrected charge observed 893.7252308894982
# Mean corrected charge observed 238.97297992345688
# Ratio 3.739858921187486
# 155
# 267
# Total charge 69309.07996213753
# distance between first and last doms 1019.1970431656232
# Average charge per meter, dividing total charge over the distance of first/last dom with light 68.00361169304782
# Standard deviation 234.23716542957604
# Maximum corrected charge observed 2232.2056554386204
# Mean corrected charge observed 259.5845691465825
# Ratio 8.599146177206459
# 126
# 15
# Total charge 11152.97502610869
# distance between first and last doms 1137.4703853196352
# Average charge per meter, dividing total charge over the distance of first/last dom with light 9.805068483584867
# Standard deviation 1299.3293443467762
# Maximum corrected charge observed 5211.798139163603
# Mean corrected charge observed 743.531668407246
# Ratio 7.009517362358001
# 164
# 466
# Total charge 170711.15801368078
# distance between first and last doms 1097.619057713045
# Average charge per meter, dividing total charge over the distance of first/last dom with light 155.52860239996897
# Standard deviation 313.6897851291619
# Maximum corrected charge observed 2261.0782759362587
# Mean corrected charge observed 366.33295711090295
# Ratio 6.172194535180039
# 129
# 124
# Total charge 29311.182166812614
# distance between first and last doms 342.5100526932917
# Average charge per meter, dividing total charge over the distance of first/last dom with light 85.57758213613651
# Standard deviation 168.07896933181192
# Maximum corrected charge observed 1018.118543748294
# Mean corrected charge observed 236.380501345263
# Ratio 4.307117287399292
# 128
# 41
# Total charge 4897.272401641872
# distance between first and last doms 645.6909245158306
# Average charge per meter, dividing total charge over the distance of first/last dom with light 7.584545818595913
# Standard deviation 73.42922952598963
# Maximum corrected charge observed 389.7005117789419
# Mean corrected charge observed 119.4456683327286
# Ratio 3.2625755058223604
# 129
# 165
# Total charge 42717.374702430054
# distance between first and last doms 794.1882344249123
# Average charge per meter, dividing total charge over the distance of first/last dom with light 53.78746857583778
# Standard deviation 223.14759321816595
# Maximum corrected charge observed 1445.920993970468
# Mean corrected charge observed 258.8931800147276
# Ratio 5.585009979359882
# 129
# 77
# Total charge 15429.825861490817
# distance between first and last doms 466.18053616577976
# Average charge per meter, dividing total charge over the distance of first/last dom with light 33.098391426629135
# Standard deviation 133.33357015963034
# Maximum corrected charge observed 780.3948458443294
# Mean corrected charge observed 200.3873488505301
# Ratio 3.8944317109880515
# 128
# 64
# Total charge 8793.236471629163
# distance between first and last doms 903.252163379042
# Average charge per meter, dividing total charge over the distance of first/last dom with light 9.735084872350487
# Standard deviation 96.68516538081006
# Maximum corrected charge observed 430.6999012308143
# Mean corrected charge observed 137.39431986920567
# Ratio 3.134772249979655
# 128
# 26
# Total charge 2407.0920502549607
# distance between first and last doms 254.82567237298443
# Average charge per meter, dividing total charge over the distance of first/last dom with light 9.446034333352948
# Standard deviation 80.26763721852136
# Maximum corrected charge observed 328.0687971282872
# Mean corrected charge observed 92.58046347134464
# Ratio 3.5436072020727196
# 129
# 96
# Total charge 12381.333086111366
# distance between first and last doms 746.8836004164261
# Average charge per meter, dividing total charge over the distance of first/last dom with light 16.577326211484806
# Standard deviation 116.90686546790891
# Maximum corrected charge observed 757.3174950205718
# Mean corrected charge observed 128.9722196469934
# Ratio 5.8719427880934845
# 129
# 86
# Total charge 116059.86952794803
# distance between first and last doms 818.3268534896631
# Average charge per meter, dividing total charge over the distance of first/last dom with light 141.8258108395487
# Standard deviation 1774.2674848862055
# Maximum corrected charge observed 11069.879752725985
# Mean corrected charge observed 1349.533366604047
# Ratio 8.20274624300852
# 130
# 23
# Total charge 2054.299867003088
# distance between first and last doms 833.433039079877
# Average charge per meter, dividing total charge over the distance of first/last dom with light 2.4648649269664986
# Standard deviation 53.560458614400225
# Maximum corrected charge observed 253.81233921084026
# Mean corrected charge observed 89.31738552187339
# Ratio 2.841690200937228
# 129
# 94
# Total charge 39386.45066480741
# distance between first and last doms 924.3176644595553
# Average charge per meter, dividing total charge over the distance of first/last dom with light 42.611379376630765
# Standard deviation 294.1859497782907
# Maximum corrected charge observed 2029.957367316739
# Mean corrected charge observed 419.0047943064618
# Ratio 4.844711551992457
# 128
# 49
# Total charge 9224.88375905853
# distance between first and last doms 185.47953922505775
# Average charge per meter, dividing total charge over the distance of first/last dom with light 49.73531742423196
# Standard deviation 310.9461224485946
# Maximum corrected charge observed 2225.9233367359557
# Mean corrected charge observed 188.26293385833733
# Ratio 11.823481612216357
# 129
# 82
# Total charge 9659.047171305663
# distance between first and last doms 291.76707779917496
# Average charge per meter, dividing total charge over the distance of first/last dom with light 33.10533609262812
# Standard deviation 64.95177736536986
# Maximum corrected charge observed 297.28530959124345
# Mean corrected charge observed 117.79325818665443
# Ratio 2.523788832805415
# 145
# 30
# Total charge 5742.754486987202
# distance between first and last doms 455.9257512890429
# Average charge per meter, dividing total charge over the distance of first/last dom with light 12.595810766886189
# Standard deviation 156.0824609740127
# Maximum corrected charge observed 858.9989211221847
# Mean corrected charge observed 191.42514956624007
# Ratio 4.487388010763652
# 129
# 101
# Total charge 15804.293327097672
# distance between first and last doms 157.9833657587367
# Average charge per meter, dividing total charge over the distance of first/last dom with light 100.03770492668892
# Standard deviation 144.91484980653289
# Maximum corrected charge observed 1144.820628564135
# Mean corrected charge observed 156.4781517534423
# Ratio 7.316169163142934
# 128
# 37
# Total charge 4115.660962995941
# distance between first and last doms 1088.2830715642342
# Average charge per meter, dividing total charge over the distance of first/last dom with light 3.78179268844119
# Standard deviation 65.42314308574493
# Maximum corrected charge observed 256.1675929607532
# Mean corrected charge observed 111.23408008097138
# Ratio 2.3029596035161113
# 129
# 103
# Total charge 20156.11535713012
# distance between first and last doms 878.3447042669918
# Average charge per meter, dividing total charge over the distance of first/last dom with light 22.947841842971062
# Standard deviation 191.58764082685317
# Maximum corrected charge observed 1479.2046496398946
# Mean corrected charge observed 195.69044036048658
# Ratio 7.558900919815052
# 128
# 106
# Total charge 18877.036840783665
# distance between first and last doms 207.81368135764046
# Average charge per meter, dividing total charge over the distance of first/last dom with light 90.83635262828008
# Standard deviation 133.7841138694207
# Maximum corrected charge observed 778.5094257164694
# Mean corrected charge observed 178.08525321494022
# Ratio 4.3715547001348085
# 129
# 52
# Total charge 8231.613845888183
# distance between first and last doms 672.613502671122
# Average charge per meter, dividing total charge over the distance of first/last dom with light 12.238252448394684
# Standard deviation 126.65714071441201
# Maximum corrected charge observed 656.7529129781477
# Mean corrected charge observed 158.30026626708045
# Ratio 4.148779584931903
# 129
# 36
# Total charge 13929.646972514338
# distance between first and last doms 1139.664083504789
# Average charge per meter, dividing total charge over the distance of first/last dom with light 12.222590124694234
# Standard deviation 339.8976494991567
# Maximum corrected charge observed 1643.2623652482457
# Mean corrected charge observed 386.9346381253983
# Ratio 4.2468732528300945
# 128
# 22
# Total charge 18994.124648480007
# distance between first and last doms 551.0229336337268
# Average charge per meter, dividing total charge over the distance of first/last dom with light 34.470660818458214
# Standard deviation 802.3435985007312
# Maximum corrected charge observed 2995.983881343661
# Mean corrected charge observed 863.3693022036367
# Ratio 3.470107025692025
# 129
# 95
# Total charge 59998.62858807381
# distance between first and last doms 514.8483300834797
# Average charge per meter, dividing total charge over the distance of first/last dom with light 116.536511982753
# Standard deviation 438.8810911149931
# Maximum corrected charge observed 2913.1049625321048
# Mean corrected charge observed 631.5645114534085
# Ratio 4.6125216184617885
# 129
# 94
# Total charge 17439.132736474734
# distance between first and last doms 1127.0585785173862
# Average charge per meter, dividing total charge over the distance of first/last dom with light 15.473137837622799
# Standard deviation 119.55582621700104
# Maximum corrected charge observed 652.8800459722956
# Mean corrected charge observed 185.52268868590141
# Ratio 3.5191385517145672
# 128
# 34
# Total charge 4149.970691636682
# distance between first and last doms 417.2516828092604
# Average charge per meter, dividing total charge over the distance of first/last dom with light 9.9459651395433
# Standard deviation 88.3782071011683
# Maximum corrected charge observed 349.1842392311152
# Mean corrected charge observed 122.05796151872595
# Ratio 2.8608067420292276
# 128
# 47
# Total charge 4789.542234181997
# distance between first and last doms 830.1477362595214
# Average charge per meter, dividing total charge over the distance of first/last dom with light 5.769505866224137
# Standard deviation 68.52053874394984
# Maximum corrected charge observed 322.4215208863177
# Mean corrected charge observed 101.90515391876589
# Ratio 3.163937332780414
# 133
# 51
# Total charge 7342.13093115781
# distance between first and last doms 677.8868292770429
# Average charge per meter, dividing total charge over the distance of first/last dom with light 10.830909547229428
# Standard deviation 94.54440786425992
# Maximum corrected charge observed 466.16561930294114
# Mean corrected charge observed 143.9633515913296
# Ratio 3.238085347069793
# 129
# 158
# Total charge 53034.2819432494
# distance between first and last doms 669.210034923749
# Average charge per meter, dividing total charge over the distance of first/last dom with light 79.24908350977167
# Standard deviation 265.4594319099696
# Maximum corrected charge observed 1514.2333162179834
# Mean corrected charge observed 335.66001229904685
# Ratio 4.511211525753386

# %%
def inf(num):
    infile = dataio.I3File(os.path.join(files_dir,file_list[num]))
    frame = infile.pop_physics()   
    return frame

# %%
print(inf(0))
# Out:
# [ I3Frame  (Physics):
#   'AnalysisMuons' [Physics] ==> TreeBase::Tree<I3Particle, I3ParticleID, __gnu_cxx::hash<I3ParticleID> > (174)
#   'BackgroundCLSim_intermediatePhotons' [DAQ] ==> I3Map<ModuleKey, I3Vector<I3Photon> > (3167)
#   'BackgroundI3MCPESeriesMap_0.990' [DAQ] ==> I3Map<OMKey, vector<I3MCPE> > (90)
#   'BackgroundI3MCTree' [DAQ] ==> TreeBase::Tree<I3Particle, I3ParticleID, __gnu_cxx::hash<I3ParticleID> > (1786)
#   'BackgroundI3MCTree_preMuonProp' [DAQ] ==> TreeBase::Tree<I3Particle, I3ParticleID, __gnu_cxx::hash<I3ParticleID> > (918)
#   'BackgroundMMCTrackList' [DAQ] ==> I3Vector<I3MMCTrack> (304)
#   'BeaconLaunches' [DAQ] ==> I3Map<OMKey, vector<I3DOMLaunch> > (46)
#   'CalibratedWaveformRange' [DAQ] ==> I3TimeWindow (48)
#   'CascadeFilter_13' [Physics] ==> I3PODHolder<bool> (27)
#   'CorsikaInteractionHeight' [DAQ] ==> I3PODHolder<double> (36)
#   'CorsikaWeightMap' [DAQ] ==> I3Map<string, double> (482)
#   'DCAnalysisHits' [Physics] ==> I3PODHolder<double> (36)
#   'DCNHits' [Physics] ==> I3PODHolder<double> (36)
#   'DSTTriggers' [DAQ] ==> I3SuperDSTTriggerSeries (64)
#   'DebiasingForLineFitNew' [Physics] ==> I3RecoPulseSeriesMapMask (213)
#   'DeepCoreFilter_13' [Physics] ==> I3PODHolder<bool> (27)
#   'DeepCoreFilter_TwoLayerExp_13' [Physics] ==> I3PODHolder<bool> (27)
#   'DeepCoreSMTTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'DistAboveEndpoint' [Physics] ==> I3Vector<double> (646)
#   'DistToBorder' [Physics] ==> I3PODHolder<double> (36)
#   'EHEFilter_13' [Physics] ==> I3PODHolder<bool> (27)
#   'EventCharge' [Physics] ==> I3PODHolder<double> (36)
#   'FSSCandidate_13' [Physics] ==> I3PODHolder<bool> (27)
#   'FSSFilter_13' [Physics] ==> I3PODHolder<bool> (27)
#   'FSSFilter_STWC_pulsesTimeRange' [Physics] ==> I3TimeWindow (48)
#   'FilterMask' [Physics] ==> I3Map<string, I3FilterResult> (891)
#   'FiniteRecoCutsDOMeff' [Physics] ==> I3FiniteCuts (80)
#   'FiniteRecoFitDOMeff' [Physics] ==> I3Particle (150)
#   'FiniteRecoLLHRatio' [Physics] ==> I3PODHolder<double> (36)
#   'FiniteRecoLlhDOMeff' [Physics] ==> I3StartStopParams (61)
#   'FiniteReco_FiniteRecoLlhDOMeff_rusage' [Physics] ==> I3RUsage (52)
#   'FiniteReco_VertexRecoDOMeff_rusage' [Physics] ==> I3RUsage (52)
#   'FixedRateTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'GCFilter_13' [Physics] ==> I3PODHolder<bool> (27)
#   'HESEFilter_15' [Physics] ==> I3PODHolder<bool> (27)
#   'HitMultiplicityValues' [Physics] ==> I3HitMultiplicityValues (63)
#   'HitStatisticsValues' [Physics] ==> I3HitStatisticsValues (155)
#   'I3EventHeader' [Physics] ==> I3EventHeader (109)
#   'I3MCPESeriesMap_0.990' [DAQ] ==> I3Map<OMKey, vector<I3MCPE> > (7081)
#   'I3MCPESeriesMap_0.990WithoutNoise' [DAQ] ==> I3Map<OMKey, vector<I3MCPE> > (3184)
#   'I3MCPulseSeriesMap' [DAQ] ==> I3Map<OMKey, vector<I3MCPulse> > (5594)
#   'I3MCPulseSeriesMapParticleIDMap' [DAQ] ==> I3Map<OMKey, map<I3ParticleID, vector<unsigned int, allocator<unsigned int> >, less<I3ParticleID>, allocator<pair<I3ParticleID const, vector<unsigned int, allocator<unsigned int> > > > > > (5521)
#   'I3MCTree' [DAQ] ==> TreeBase::Tree<I3Particle, I3ParticleID, __gnu_cxx::hash<I3ParticleID> > (6630)
#   'I3SuperDST' [DAQ] ==> I3SuperDST (469)
#   'I3TriggerHierarchy' [Physics] ==> I3Tree<I3Trigger> (440)
#   'I3Triggers' [DAQ] ==> I3Tree<I3Trigger> (230)
#   'ICAnalysisHits' [Physics] ==> I3PODHolder<double> (36)
#   'ICNHits' [Physics] ==> I3PODHolder<double> (36)
#   'IceTopSMTTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'IceTopVolumeTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'ImpactAngle' [Physics] ==> I3Vector<double> (646)
#   'InIceDSTPulses' [DAQ] ==> I3RecoPulseSeriesMapMask (416)
#   'InIcePulses' [DAQ] ==> I3RecoPulseSeriesMapMask (420)
#   'InIceRawData' [DAQ] ==> I3Map<OMKey, vector<I3DOMLaunch> > (15140)
#   'InIceSMTTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'InIceStringTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'L4VetoLayer0' [Physics] ==> I3PODHolder<double> (36)
#   'L4VetoLayer1' [Physics] ==> I3PODHolder<double> (36)
#   'L4VetoLayerPulses0' [Physics] ==> I3RecoPulseSeriesMapMask (102)
#   'L4VetoLayerPulses1' [Physics] ==> I3RecoPulseSeriesMapMask (102)
#   'L4VetoLayerQTot' [Physics] ==> I3PODHolder<double> (36)
#   'L4VetoLayerVertexTime' [Physics] ==> I3PODHolder<double> (36)
#   'LineFitDOMeff' [Physics] ==> I3Particle (150)
#   'LineFitDOMeffParams' [Physics] ==> I3LineFitParams (71)
#   'LowUp_13' [Physics] ==> I3PODHolder<bool> (27)
#   'MESEFilter_15' [Physics] ==> I3PODHolder<bool> (27)
#   'MMCTrackList' [DAQ] ==> I3Vector<I3MMCTrack> (304)
#   'MPEFitCramerRaoDOMeffParams' [Physics] ==> CramerRaoParams (135)
#   'MPEFitDOMeff' [Physics] ==> I3Particle (150)
#   'MPEFitDOMeffFitParams' [Physics] ==> I3LogLikelihoodFitParams (68)
#   'MuEx' [Physics] ==> I3Particle (150)
#   'MuEx_EnUnc' [Physics] ==> I3PODHolder<double> (36)
#   'MuEx_Sigma' [Physics] ==> I3PODHolder<double> (36)
#   'MuEx_r' [Physics] ==> I3PODHolder<double> (36)
#   'MuEx_rlle' [Physics] ==> I3PODHolder<double> (36)
#   'MuEx_rllt' [Physics] ==> I3PODHolder<double> (36)
#   'MuonFilter_13' [Physics] ==> I3PODHolder<bool> (27)
#   'NDirDoms' [Physics] ==> I3PODHolder<double> (36)
#   'NumVisibleMuons_analysis_region' [Physics] ==> I3PODHolder<double> (36)
#   'OM' [Physics] ==> I3Vector<double> (646)
#   'PhotonArrivalAngle' [Physics] ==> I3Vector<double> (646)
#   'PhysMinBiasTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'PoleEHESummaryPulseInfo' [Physics] ==> I3PortiaEvent (172)
#   'PoleMuonLinefit' [Physics] ==> I3Particle (150)
#   'PoleMuonLinefitParams' [Physics] ==> I3LineFitParams (71)
#   'PoleMuonLlhFit' [Physics] ==> I3Particle (150)
#   'PoleMuonLlhFitDirectHitsBaseA' [Physics] ==> I3DirectHitsValues (126)
#   'PoleMuonLlhFitDirectHitsBaseB' [Physics] ==> I3DirectHitsValues (126)
#   'PoleMuonLlhFitDirectHitsBaseC' [Physics] ==> I3DirectHitsValues (126)
#   'PoleMuonLlhFitDirectHitsBaseD' [Physics] ==> I3DirectHitsValues (126)
#   'PoleMuonLlhFitFitParams' [Physics] ==> I3LogLikelihoodFitParams (68)
#   'PoleMuonLlhFitMuE' [Physics] ==> I3Particle (150)
#   'PoleMuonLlhFit_Finite' [Physics] ==> I3Particle (150)
#   'PoleMuonLlhFit_FiniteCuts' [Physics] ==> I3FiniteCuts (80)
#   'PolyplopiaInfo' [DAQ] ==> I3Map<string, double> (69)
#   'PolyplopiaPrimary' [DAQ] ==> I3Particle (150)
#   'PrimaryParticle' [DAQ] ==> I3Particle (150)
#   'RNGState' [DAQ] ==> I3SPRNGRandomServiceState (73)
#   'RTTWOfflinePulses_FR_WIMP_DOMeff' [Physics] ==> I3RecoPulseSeriesMapMask (335)
#   'RecoDistance' [Physics] ==> I3Vector<double> (646)
#   'RecoEndpoint' [Physics] ==> I3Position (54)
#   'RecoEndpointZ' [Physics] ==> I3PODHolder<double> (36)
#   'SPEFit2DOMeff' [Physics] ==> I3Particle (150)
#   'SPEFit2DOMeffFitParams' [Physics] ==> I3LogLikelihoodFitParams (68)
#   'SPEFitSingleDOMeff' [Physics] ==> I3Particle (150)
#   'SPEFitSingleDOMeffFitParams' [Physics] ==> I3LogLikelihoodFitParams (68)
#   'SRTInIcePulsesDOMeff' [Physics] ==> I3RecoPulseSeriesMapMask (290)
#   'ScintMinBiasTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'SignalCLSim_intermediatePhotons' [DAQ] ==> I3Map<ModuleKey, I3Vector<I3Photon> > (82751)
#   'SignalI3MCPESeriesMap_0.990' [DAQ] ==> I3Map<OMKey, vector<I3MCPE> > (3143)
#   'SlowParticleTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'SplineMPE' [Physics] ==> I3Particle (150)
#   'SplineMPEDirectHitsA' [Physics] ==> I3DirectHitsValues (126)
#   'SplineMPEDirectHitsB' [Physics] ==> I3DirectHitsValues (126)
#   'SplineMPEDirectHitsC' [Physics] ==> I3DirectHitsValues (126)
#   'SplineMPEDirectHitsD' [Physics] ==> I3DirectHitsValues (126)
#   'SplineMPEFitParams' [Physics] ==> I3LogLikelihoodFitParams (68)
#   'SplitInIceDSTPulses' [Physics] ==> I3RecoPulseSeriesMapMask (420)
#   'SplitInIcePulses' [Physics] ==> I3RecoPulseSeriesMapMask (425)
#   'SplitUncleanedInIcePulsesHLC_NoDC' [Physics] ==> I3RecoPulseSeriesMapMask (158)
#   'String' [Physics] ==> I3Vector<double> (646)
#   'TWOfflinePulses_FR_WIMP_DOMeff' [Physics] ==> I3RecoPulseSeriesMapMask (382)
#   'TWOfflinePulses_FR_WIMP_DOMeffTimeRange' [Physics] ==> I3TimeWindow (48)
#   'TimeShift' [DAQ] ==> I3PODHolder<double> (36)
#   'TotalCharge' [Physics] ==> I3Vector<double> (646)
#   'TriggerSplitterLaunchWindow' [Physics] ==> I3TimeWindow (48)
#   'TruthDistance' [Physics] ==> I3Vector<double> (646)
#   'TruthEndpoint' [Physics] ==> I3Position (54)
#   'TruthEnergy' [Physics] ==> I3PODHolder<double> (36)
#   'TruthMuon' [Physics] ==> I3Particle (150)
#   'VEF_13' [Physics] ==> I3PODHolder<bool> (27)
#   'VolumeTrigTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'rlogl' [Physics] ==> I3PODHolder<double> (36)
# ]

# %%
pulses = inf(0)['SRTInIcePulsesDOMeff'].apply(inf(0))
one_dom = pulses.items()

# %%
charge = []
for i in range(16):  #Sasha: I have 16 here, because it is the first time when we met this "triplet" 
    
    for pulse in one_dom[i][1]:
        char = 0
        char += pulse.charge
        print(char) #Sasha: there are three last values of charge
    charge.append(char) #Sasha: they do not write down in this array, only one of them is written.  
        
print(charge)
#Sasha: but in the next cell I consider them as a sum, I mean I will have not 1.17, 0.925, 1.225 separately, but their sum
# Out:
# 0.824999988079071
# 1.1749999523162842
# 0.875
# 0.824999988079071
# 0.2750000059604645
# 1.475000023841858
# 1.1749999523162842
# 0.824999988079071
# 1.125
# 1.5750000476837158
# 1.4249999523162842
# 0.32499998807907104
# 1.0750000476837158
# 1.475000023841858
# 0.875
# 1.1749999523162842
# 0.925000011920929
# 1.225000023841858
# [0.824999988079071, 1.1749999523162842, 0.875, 0.824999988079071, 0.2750000059604645, 1.475000023841858, 1.1749999523162842, 0.824999988079071, 1.125, 1.5750000476837158, 1.4249999523162842, 0.32499998807907104, 1.0750000476837158, 1.475000023841858, 0.875, 1.225000023841858]

# %%
charge = []
for i in range(len(one_dom)):  
    char = 0
    for pulse in one_dom[i][1]:
        char += pulse.charge
        
        
    charge.append(char)
        
print(charge)
# Out:
# [0.824999988079071, 1.1749999523162842, 0.875, 0.824999988079071, 0.2750000059604645, 1.475000023841858, 1.1749999523162842, 0.824999988079071, 1.125, 1.5750000476837158, 1.4249999523162842, 0.32499998807907104, 1.0750000476837158, 1.475000023841858, 0.875, 3.324999988079071, 0.625, 3.3000000715255737, 1.125, 0.7749999761581421, 1.375, 0.925000011920929, 1.0750000476837158, 0.675000011920929, 1.375, 1.3250000476837158, 1.0750000476837158, 1.3499999642372131, 1.375, 0.875, 2.649999976158142, 0.7250000238418579, 0.4749999940395355, 1.4249999523162842, 0.7749999761581421, 1.024999976158142, 1.4249999523162842, 0.7250000238418579, 0.22499999403953552, 1.125, 1.1749999523162842, 1.274999976158142, 0.875, 0.925000011920929, 0.42500001192092896, 0.875, 2.574999988079071, 0.875, 2.900000035762787, 3.774999976158142, 3.475000113248825]

# %%
gcd_file = '/cvmfs/icecube.opensciencegrid.org/data/GCD/GeoCalibDetectorStatus_IC86_Merged.i3.gz'

gfile = dataio.I3File(gcd_file)
gframe = gfile.pop_frame()
print(gframe)
geometry = gframe['I3Geometry']
# Out:
# [ I3Frame  (Geometry):
#   'I3Geometry' [Geometry] ==> I3Geometry (641528)
# ]

# %%
mydom = []
for i in range(len(one_dom)):
    dom = geometry.omgeo[one_dom[i][0]]    
    mydom.append(dom)  
    
print(len(mydom))
#print(mydom[0])
# Out:
# 51

# %%
mmctracks = inf(0)['MMCTrackList']
track = mmctracks[0].particle
print(track)
# Out:
# [ I3Particle MajorID : 13469127016857373990
#              MinorID : 846
#               Zenith : 0.400847
#              Azimuth : 1.80333
#                    X : -227.484
#                    Y : 1017.22
#                    Z : 1949.99
#                 Time : 3536.68
#               Energy : 1054.01
#                Speed : 0.299792
#               Length : 3125.59
#                 Type : MuPlus
#         PDG encoding : -13
#                Shape : StartingTrack
#               Status : NotSet
#             Location : InIce
# ]

# %%
distance = []
for i in range(len(mydom)):
    d = phys_services.I3Calculator.cherenkov_distance(track, mydom[i].position)
    distance.append(d)
print(len(distance))
# Out:
# 51

# %%
corrected_charge = []
for i in range(len(distance)):
# This is for adding also the attenuation (absorption + scattering)
    att_length = 50. # Typical attenuation length in icecube
    corrected = charge[i]*distance[i]#*np.exp(distance/att_length)
    corrected_charge.append(corrected)

# %%
print(len(corrected_charge))
print(corrected_charge)
# Out:
# 51
# [222.0763055078901, 167.65234550125294, 90.87879437146664, 70.22624541320249, 32.3280058807941, 87.84635247531457, 58.48567357188964, 43.853323474581885, 199.65093749494238, 205.83572456677518, 101.78875708003031, 20.087685112520425, 56.326474720920636, 63.917247745306305, 30.530444785473144, 91.92426364795048, 14.230792672602277, 84.02980064662638, 145.34649795757636, 111.39816999261477, 420.42546298068703, 200.25207647815236, 175.6844459128978, 94.48273255331011, 161.179778497579, 140.79109625569555, 110.38414462387806, 80.54971137983249, 79.88749828800925, 48.8141967257675, 155.96482979729348, 45.35664547689054, 75.50349198575303, 351.0134498294823, 153.79620421796307, 200.1332633587479, 269.3021013764831, 134.78485505776138, 48.89932423766513, 115.99762021723895, 98.24075255388614, 101.74091060807486, 63.26580603753744, 63.48418668450139, 23.245831617524548, 39.831076130185615, 110.32993059738524, 35.376758412388426, 106.06636885481633, 128.34913355697762, 118.64307049674646]

# %%
# Try to put it inside a function so that you can pass the puse series to the function, 
# and obtain a list of corrected charges
# Consider looking only at DOMs "nearby" (within a maximum distance of 150-200m, no further)

# %%
phys_services.I3Calculator.closest_approach_distance
# Out:
# <function phys-services.I3Calculator.closest_approach_distance>

# %%
nfiles = 2

char = []

for i in range(nfiles):
    with dataio.I3File(os.path.join(files_dir, file_list[i])) as infile:
        for frame in infile:  
            frame = infile.pop_physics()             
            fr.append(frame)
            pulses = frame['SRTInIcePulsesDOMeff'].apply(frame)
        
print(len(pulses))
#print(pulses)
zero = []
one = []


for i in range(len(pulses)):
    one_dom = pulses.popitem()
   
    charge = 0
    for pulse in one_dom[1]:
        charge += pulse.charge
    #print(charge)
    char.append(charge)
    zero.append(one_dom[0])
    one.append(one_dom[1])
    #print(one_dom[0])
    
print(len(char))
#print(char)
#print(zero)
# Out:
# 88
# 88

# %%
gcd_file = '/cvmfs/icecube.opensciencegrid.org/data/GCD/GeoCalibDetectorStatus_IC86_Merged.i3.gz'

gfile = dataio.I3File(gcd_file)

dom=[]
tr=[]
dist = []


for i in range(nfiles):
    with dataio.I3File(os.path.join(files_dir, file_list[i])) as infile:
        for frame in infile:  
            frame = infile.pop_physics()             
            fr.append(frame)
        
            mmctracks = frame['MMCTrackList']
            track = mmctracks[0].particle
            tr.append(track)
        
        gframe = gfile.pop_frame()    
        geometry = gframe['I3Geometry']

for j in range(len(zero)):
    mydom = geometry.omgeo[zero[j]]
    dom.append(mydom)
           
    distance = phys_services.I3Calculator.cherenkov_distance(track, mydom.position)
    dist.append(distance)
        
print(len(dist))    
print(len(tr))
print(len(dom))
# Out:
# 88
# 2588
# 88

# %%
def cor_char(char, dist):

  corrected_charge = char * dist
  return corrected_charge

cor_char(5,10)
# Out:
# 50

# %%
# Out:
# 50

# %%
list_of_char = []

for charge in range(2):
    for distance in range(2):
        list_of_char.append(cor_char(charge,distance))

# %%
print(list_of_char)
# Out:
# [0, 0, 0, 1]
