# %%
from icecube import icetray, dataio, dataclasses, simclasses, phys_services, recclasses
import os, sys
import numpy as np
import matplotlib as mpl
from matplotlib.colors import LogNorm, Normalize
import matplotlib.pyplot as plt
import timeit as time
import math
from datetime import datetime

# %%
# Added by JP
# Define the directory of your files
files_dir = '/data/icecube/domeff_analysis/reco_sim_nominal/0000000-0000999'
# List the contents of the entire directory
file_list_aux = os.listdir(files_dir)
# Only keep those that are I3 files
file_list = [x for x in file_list_aux if '.i3.bz2' in x]
print('Total files', len(file_list))
# Out:
# Total files 966

# %%
#I would recommend you write a function that takes a frame as input 
#and returns the corrected charge for that event. 
#Inside, the function should pick the muon and loop over all the doms that have seen light, 
#and return the corrected charges of all doms, as an array. So each event gives you an array as the output.

# %%
# Now decide how many files to loop over
nfiles = 1 # This can be len(file_list)

# %%
def func(frame):
    pulses = frame['SRTInIcePulsesDOMeff'].apply(frame)
    one_dom = pulses.items()
    charge = []
    
    for i in range(len(one_dom)):  
        char = 0
        for pulse in one_dom[i][1]:
            char += pulse.charge        
        if char > 0:
            charge.append(char)
        
    gcd_file = '/cvmfs/icecube.opensciencegrid.org/data/GCD/GeoCalibDetectorStatus_IC86_Merged.i3.gz'
    gfile = dataio.I3File(gcd_file)
    gframe = gfile.pop_frame()
    geometry = gframe['I3Geometry']
    
    mydom = []
    for i in range(len(one_dom)):
        dom = geometry.omgeo[one_dom[i][0]]    
        mydom.append(dom) 
        
    mmctracks = frame['MMCTrackList']
    track = mmctracks[0].particle
    
    distance = []
    for i in range(len(mydom)):
        d = phys_services.I3Calculator.cherenkov_distance(track, mydom[i].position)
        distance.append(d)
    corrected_charge = []
    for i in range(len(distance)):
        att_length = 50. 
        corrected = charge[i]*distance[i]
        corrected_charge.append(corrected)
    
    return corrected_charge

# %%
for i in range(nfiles):
    infile = dataio.I3File(os.path.join(files_dir,file_list[i]))
    frame = infile.pop_physics()
    print(len(frame))
    print(len(func(frame)))
    print('Total charge', np.sum(func(frame)) )
    print('Standard deviation', np.std(func(frame)))
    print('Maximum corrected charge observed', np.max(func(frame)) )
    print('Mean corrected charge observed', np.mean(func(frame)) )
    print('Ratio',np.max(func(frame))/np.mean(func(frame)) )
# Out:
# 133
# 51
# Total charge 5850.190597420843
# Standard deviation 79.81515272200875
# Maximum corrected charge observed 420.42546298068703
# Mean corrected charge observed 114.70961955727144
# Ratio 3.6651282133385497

# %%
phys_services.I3Calculator.distance#(between first and last dom?)
# Out:
# <function phys-services.I3Calculator.distance>

# %%
for i in range(nfiles):
    with dataio.I3File(os.path.join(files_dir, file_list[i])) as infile:
        for frame in infile:
            if infile.stream.id != 'P': continue
                
            print(len(frame))    
            print(len(func(frame)))
            print('Total charge', np.sum(func(frame)) )
            print('Standard deviation', np.std(func(frame)))
            print('Maximum corrected charge observed', np.max(func(frame)) )
            print('Mean corrected charge observed', np.mean(func(frame)) )
            print('Ratio',np.max(func(frame))/np.mean(func(frame)) )
            

#print(func(frame))
# Out:
# 133
# 51
# Total charge 5850.190597420843
# Standard deviation 79.81515272200875
# Maximum corrected charge observed 420.42546298068703
# Mean corrected charge observed 114.70961955727144
# Ratio 3.6651282133385497
# 129
# 36
# Total charge 4899.764818928101
# Standard deviation 94.09463146909916
# Maximum corrected charge observed 542.2863779954413
# Mean corrected charge observed 136.10457830355836
# Ratio 3.98433605066512
# 146
# 31
# Total charge 3468.7989330663177
# Standard deviation 94.47281167065323
# Maximum corrected charge observed 436.15178967775745
# Mean corrected charge observed 111.89673977633282
# Ratio 3.8978060535952053
# 126
# 20
# Total charge 1510.0398739467903
# Standard deviation 65.48790599786271
# Maximum corrected charge observed 249.18149610412462
# Mean corrected charge observed 75.50199369733951
# Ratio 3.3003300164894203
# 131
# 22
# Total charge 2500.242137474859
# Standard deviation 85.91812477718334
# Maximum corrected charge observed 354.4744078045578
# Mean corrected charge observed 113.64736988522087
# Ratio 3.1190726909259956
# 127
# 30
# Total charge 2267.894305371064
# Standard deviation 62.185161173239536
# Maximum corrected charge observed 325.0110142960266
# Mean corrected charge observed 75.59647684570214
# Ratio 4.299287848551428
# 127
# 17
# Total charge 1863.8573429410535
# Standard deviation 93.0038928577961
# Maximum corrected charge observed 405.4126536282507
# Mean corrected charge observed 109.63866723182667
# Ratio 3.69771599622806
# 127
# 24
# Total charge 6391.264170031948
# Standard deviation 490.245792196651
# Maximum corrected charge observed 1795.5883511376094
# Mean corrected charge observed 266.30267375133116
# Ratio 6.742659868350773
# 128
# 49
# Total charge 5373.428173364955
# Standard deviation 81.23826469582981
# Maximum corrected charge observed 359.1084068905708
# Mean corrected charge observed 109.66179945642766
# Ratio 3.27469008050754
# 132
# 88
# Total charge 9603.10082526286
# Standard deviation 70.3815677490142
# Maximum corrected charge observed 345.83321841209784
# Mean corrected charge observed 109.1261457416234
# Ratio 3.1691142032169153
# 128
# 94
# Total charge 10194.270781457797
# Standard deviation 83.5296099259362
# Maximum corrected charge observed 414.20181381028675
# Mean corrected charge observed 108.44968916444465
# Ratio 3.8192992253045874
# 133
# 137
# Total charge 11556.977645797411
# Standard deviation 59.991663751761976
# Maximum corrected charge observed 334.5222507566147
# Mean corrected charge observed 84.35750106421467
# Ratio 3.965530587516686
# 129
# 30
# Total charge 3320.733220590005
# Standard deviation 95.76894169838295
# Maximum corrected charge observed 531.4915743675974
# Mean corrected charge observed 110.69110735300018
# Ratio 4.801574282499866
# 128
# 21
# Total charge 3005.287527507836
# Standard deviation 122.3046075924416
# Maximum corrected charge observed 591.3281278906959
# Mean corrected charge observed 143.1089298813255
# Ratio 4.132014182350889
# 157
# 68
# Total charge 6929.613133561947
# Standard deviation 91.36439295321331
# Maximum corrected charge observed 559.5191131168281
# Mean corrected charge observed 101.90607549355803
# Ratio 5.490537344382356
# 129
# 84
# Total charge 100816.51909086997
# Standard deviation 789.9972232114688
# Maximum corrected charge observed 4096.908972567016
# Mean corrected charge observed 1200.1966558436902
# Ratio 3.413531401391093
# 148
# 22
# Total charge 22581.68108548723
# Standard deviation 504.5614384784154
# Maximum corrected charge observed 2402.3960989534658
# Mean corrected charge observed 1026.4400493403286
# Ratio 2.3405128243947955
# 129
# 105
# Total charge 8448.964633599271
# Standard deviation 57.05454277128008
# Maximum corrected charge observed 326.9651346783608
# Mean corrected charge observed 80.46632984380258
# Ratio 4.063378251661907
# 149
# 12
# Total charge 1588.7936907298981
# Standard deviation 99.57198429488484
# Maximum corrected charge observed 336.4407766581338
# Mean corrected charge observed 132.3994742274915
# Ratio 2.541103570245712
# 129
# 65
# Total charge 9853.933107798317
# Standard deviation 103.85483551368233
# Maximum corrected charge observed 576.620823061622
# Mean corrected charge observed 151.59897088920488
# Ratio 3.8035932544887894
# 129
# 58
# Total charge 36845.85869719349
# Standard deviation 514.8912494908476
# Maximum corrected charge observed 2795.826764787151
# Mean corrected charge observed 635.2734258136809
# Ratio 4.400981768135754
# 147
# 101
# Total charge 9285.31745937075
# Standard deviation 53.11174383323576
# Maximum corrected charge observed 295.8536160701262
# Mean corrected charge observed 91.93383623139357
# Ratio 3.21811455061524
# 126
# 10
# Total charge 5285.025513688976
# Standard deviation 769.1730194301781
# Maximum corrected charge observed 2605.5576103971725
# Mean corrected charge observed 528.5025513688977
# Ratio 4.9300757463675495
# 132
# 27
# Total charge 2982.87524276316
# Standard deviation 82.96994007827756
# Maximum corrected charge observed 297.2397305443838
# Mean corrected charge observed 110.47686084307999
# Ratio 2.6905157177354955
# 131
# 18
# Total charge 1745.3317390923348
# Standard deviation 90.19005174308906
# Maximum corrected charge observed 321.1305027752369
# Mean corrected charge observed 96.9628743940186
# Ratio 3.3118913272959514
# 179
# 68
# Total charge 14863.613030363762
# Standard deviation 131.372540946225
# Maximum corrected charge observed 604.2514428725361
# Mean corrected charge observed 218.58254456417296
# Ratio 2.7644084941793503
# 133
# 39
# Total charge 4288.67637108933
# Standard deviation 54.83356242056872
# Maximum corrected charge observed 235.95355682162347
# Mean corrected charge observed 109.96606079716231
# Ratio 2.145694363435016
# 129
# 95
# Total charge 14585.841365851275
# Standard deviation 120.30194469966645
# Maximum corrected charge observed 750.679113427092
# Mean corrected charge observed 153.53517227211867
# Ratio 4.88929736631697
# 146
# 51
# Total charge 5253.5269546634545
# Standard deviation 85.08249312184041
# Maximum corrected charge observed 368.5859056216557
# Mean corrected charge observed 103.01033244438146
# Ratio 3.578144996480493
# 148
# 41
# Total charge 5593.080841790278
# Standard deviation 104.2251490660334
# Maximum corrected charge observed 508.23154454222714
# Mean corrected charge observed 136.41660589732385
# Ratio 3.725584148639175
# 129
# 32
# Total charge 3275.2262590882633
# Standard deviation 66.84564910124855
# Maximum corrected charge observed 313.3981895335944
# Mean corrected charge observed 102.35082059650823
# Ratio 3.0619997739840907
# 149
# 20
# Total charge 1706.080755291036
# Standard deviation 65.86927424657438
# Maximum corrected charge observed 306.2627207343603
# Mean corrected charge observed 85.3040377645518
# Ratio 3.5902488177602794
# 127
# 17
# Total charge 1229.6231219024646
# Standard deviation 60.39594146539811
# Maximum corrected charge observed 247.45214792436977
# Mean corrected charge observed 72.33077187661557
# Ratio 3.4211185848601553
# 129
# 46
# Total charge 55456.0419771393
# Standard deviation 746.9674870934448
# Maximum corrected charge observed 3463.9178924269095
# Mean corrected charge observed 1205.566129937811
# Ratio 2.873270745094336
# 129
# 40
# Total charge 4347.315157434619
# Standard deviation 92.98985632670019
# Maximum corrected charge observed 483.84767718280995
# Mean corrected charge observed 108.68287893586549
# Ratio 4.4519217922846135
# 129
# 63
# Total charge 36426.64446341717
# Standard deviation 583.7232331890903
# Maximum corrected charge observed 3551.6098488415855
# Mean corrected charge observed 578.2007057685265
# Ratio 6.142520777661272
# 145
# 29
# Total charge 31406.762525751077
# Standard deviation 571.8278329528754
# Maximum corrected charge observed 2435.2003765050017
# Mean corrected charge observed 1082.9918112327957
# Ratio 2.2485861400308784
# 128
# 31
# Total charge 3932.578514009635
# Standard deviation 118.32143986278537
# Maximum corrected charge observed 498.7601913449212
# Mean corrected charge observed 126.85737141966564
# Ratio 3.931661091218248
# 148
# 54
# Total charge 5679.345759213138
# Standard deviation 112.94591566407529
# Maximum corrected charge observed 684.1353392017119
# Mean corrected charge observed 105.17306961505811
# Ratio 6.504852826923301
# 129
# 51
# Total charge 10112.510988744421
# Standard deviation 223.06967948981625
# Maximum corrected charge observed 1257.3387874725543
# Mean corrected charge observed 198.2845291910671
# Ratio 6.341083656914967
# 127
# 101
# Total charge 14921.46547667268
# Standard deviation 114.11077113146288
# Maximum corrected charge observed 791.5577545403132
# Mean corrected charge observed 147.73728194725425
# Ratio 5.357874086399656
# 126
# 18
# Total charge 1199.5686954365826
# Standard deviation 44.13155846576749
# Maximum corrected charge observed 194.79059182906653
# Mean corrected charge observed 66.64270530203237
# Ratio 2.922909430916006
# 129
# 80
# Total charge 10245.759201560884
# Standard deviation 96.42202723258266
# Maximum corrected charge observed 611.9750921097998
# Mean corrected charge observed 128.07199001951105
# Ratio 4.778367947718848
# 129
# 51
# Total charge 12405.564664646809
# Standard deviation 512.0967424673779
# Maximum corrected charge observed 2802.6204005512154
# Mean corrected charge observed 243.24636597346682
# Ratio 11.521735954143395
# 128
# 34
# Total charge 4580.5545680390205
# Standard deviation 119.95186590186204
# Maximum corrected charge observed 548.2071100801924
# Mean corrected charge observed 134.72219317761824
# Ratio 4.069167055181725
# 128
# 54
# Total charge 47239.80273901905
# Standard deviation 593.8779750200498
# Maximum corrected charge observed 3899.2453400922973
# Mean corrected charge observed 874.811161833686
# Ratio 4.45724232864052
# 129
# 96
# Total charge 14668.30989337637
# Standard deviation 123.4138598374308
# Maximum corrected charge observed 748.4227276537258
# Mean corrected charge observed 152.79489472267053
# Ratio 4.898218157171717
# 128
# 27
# Total charge 3692.0572262792043
# Standard deviation 98.19694768188462
# Maximum corrected charge observed 402.4583621113438
# Mean corrected charge observed 136.74286023256312
# Ratio 2.943176421985539
# 129
# 14
# Total charge 1177.3982346209211
# Standard deviation 45.72131756095682
# Maximum corrected charge observed 203.05771694585317
# Mean corrected charge observed 84.09987390149436
# Ratio 2.4144830131813677
# 132
# 33
# Total charge 4381.537901835165
# Standard deviation 84.49482467793705
# Maximum corrected charge observed 333.41637554950984
# Mean corrected charge observed 132.7738758131868
# Ratio 2.5111594694925343
# 131
# 19
# Total charge 2400.5272826846035
# Standard deviation 64.23004249229166
# Maximum corrected charge observed 284.75741098358014
# Mean corrected charge observed 126.3435411939265
# Ratio 2.253834333695792
# 132
# 41
# Total charge 5829.340840736269
# Standard deviation 87.41583121099748
# Maximum corrected charge observed 344.3603902307628
# Mean corrected charge observed 142.17904489600656
# Ratio 2.4220192960406854
# 132
# 40
# Total charge 3955.1392752205584
# Standard deviation 91.8335389691649
# Maximum corrected charge observed 448.0661258917977
# Mean corrected charge observed 98.87848188051396
# Ratio 4.5314826580089145
# 129
# 82
# Total charge 8167.722156517232
# Standard deviation 66.0313100887213
# Maximum corrected charge observed 397.9844832282224
# Mean corrected charge observed 99.60636776240527
# Ratio 3.9955726944842467
# 129
# 69
# Total charge 8541.596851487506
# Standard deviation 121.80778564356332
# Maximum corrected charge observed 926.3669336905542
# Mean corrected charge observed 123.79125871721023
# Ratio 7.48329844360622
# 128
# 24
# Total charge 3009.4912653709544
# Standard deviation 96.72700121744742
# Maximum corrected charge observed 388.97387296255613
# Mean corrected charge observed 125.39546939045643
# Ratio 3.1019770877954866
# 128
# 33
# Total charge 3248.540466550583
# Standard deviation 68.68244771197033
# Maximum corrected charge observed 266.37348982734954
# Mean corrected charge observed 98.44062019850251
# Ratio 2.7059306340229825
# 127
# 18
# Total charge 1752.5528800195439
# Standard deviation 58.883212607829215
# Maximum corrected charge observed 244.82345396802836
# Mean corrected charge observed 97.36404888997465
# Ratio 2.5145159507970836
# 216
# 64
# Total charge 16334.645678633027
# Standard deviation 390.23222914424906
# Maximum corrected charge observed 1935.058291679866
# Mean corrected charge observed 255.22883872864105
# Ratio 7.581660055810611
# 127
# 35
# Total charge 3532.307909999635
# Standard deviation 82.39582468025172
# Maximum corrected charge observed 336.20144782906283
# Mean corrected charge observed 100.9230831428467
# Ratio 3.3312641405653722
# 127
# 28
# Total charge 3133.666640563312
# Standard deviation 74.70380260345124
# Maximum corrected charge observed 397.84277022605664
# Mean corrected charge observed 111.91666573440399
# Ratio 3.55481257072294
# 129
# 75
# Total charge 8913.345860805894
# Standard deviation 69.54962569306754
# Maximum corrected charge observed 318.75979339769395
# Mean corrected charge observed 118.84461147741192
# Ratio 2.682156047590586
# 132
# 85
# Total charge 9635.885861224848
# Standard deviation 75.22123358051522
# Maximum corrected charge observed 351.0816149536049
# Mean corrected charge observed 113.3633630732335
# Ratio 3.096958359702189
# 127
# 44
# Total charge 36525.37160388456
# Standard deviation 587.9825568794253
# Maximum corrected charge observed 2501.1281130339307
# Mean corrected charge observed 830.1220819064673
# Ratio 3.0129641983379276
# 128
# 34
# Total charge 3750.560289644826
# Standard deviation 62.62238576175075
# Maximum corrected charge observed 254.87372391587425
# Mean corrected charge observed 110.31059675425958
# Ratio 2.310509882234251
# 132
# 67
# Total charge 6545.925986716611
# Standard deviation 61.323119134946936
# Maximum corrected charge observed 273.6658161104931
# Mean corrected charge observed 97.70038786144195
# Ratio 2.8010719517163447
# 133
# 40
# Total charge 11462.38264342809
# Standard deviation 230.9030114247523
# Maximum corrected charge observed 874.8158048955553
# Mean corrected charge observed 286.5595660857023
# Ratio 3.052823595614747
# 129
# 72
# Total charge 9249.769248619183
# Standard deviation 116.74960920797784
# Maximum corrected charge observed 865.0655987890674
# Mean corrected charge observed 128.4690173419331
# Ratio 6.733651558076521
# 129
# 45
# Total charge 5928.76822951449
# Standard deviation 111.43057951043725
# Maximum corrected charge observed 549.0674757885022
# Mean corrected charge observed 131.75040510032198
# Ratio 4.167482258368861
# 125
# 6
# Total charge 11055.580652549255
# Standard deviation 3550.0349535132586
# Maximum corrected charge observed 9725.570038859276
# Mean corrected charge observed 1842.596775424876
# Ratio 5.278186833153825
# 129
# 38
# Total charge 31911.005793271797
# Standard deviation 504.0710703442623
# Maximum corrected charge observed 2448.2938778050984
# Mean corrected charge observed 839.7633103492578
# Ratio 2.9154570670476807
# 129
# 79
# Total charge 50968.68411479261
# Standard deviation 323.2653262485021
# Maximum corrected charge observed 1746.9299379743209
# Mean corrected charge observed 645.1732166429445
# Ratio 2.707691350028743
# 129
# 38
# Total charge 5142.234985512636
# Standard deviation 107.24905056955862
# Maximum corrected charge observed 372.6027475527372
# Mean corrected charge observed 135.3219733029641
# Ratio 2.7534534004949784
# 128
# 16
# Total charge 14697.030552771255
# Standard deviation 1010.6646162069966
# Maximum corrected charge observed 4589.668695921909
# Mean corrected charge observed 918.5644095482035
# Ratio 4.996567086873462
# 128
# 38
# Total charge 4254.534058623361
# Standard deviation 67.39629738492435
# Maximum corrected charge observed 289.628600923821
# Mean corrected charge observed 111.96142259535159
# Ratio 2.5868606722745033
# 128
# 20
# Total charge 4765.601161906153
# Standard deviation 546.9879451327355
# Maximum corrected charge observed 2531.47051580274
# Mean corrected charge observed 238.28005809530765
# Ratio 10.623929404911419
# 129
# 91
# Total charge 9843.976278867463
# Standard deviation 75.2498758571862
# Maximum corrected charge observed 332.98568596084715
# Mean corrected charge observed 108.17556350403805
# Ratio 3.0781969159644564
# 148
# 16
# Total charge 790.6898501421103
# Standard deviation 30.715737880042028
# Maximum corrected charge observed 126.5743379221996
# Mean corrected charge observed 49.4181156338819
# Ratio 2.5612943006555695
# 129
# 103
# Total charge 8389.540756996716
# Standard deviation 57.92530601406764
# Maximum corrected charge observed 289.5790674903669
# Mean corrected charge observed 81.45185200967686
# Ratio 3.555217718756887
# 129
# 25
# Total charge 1785.4010742527907
# Standard deviation 48.98141799590134
# Maximum corrected charge observed 246.22591574293733
# Mean corrected charge observed 71.41604297011163
# Ratio 3.447767553377124
# 149
# 32
# Total charge 3658.384240735078
# Standard deviation 106.56162669283925
# Maximum corrected charge observed 523.5151638477417
# Mean corrected charge observed 114.32450752297119
# Ratio 4.579203315112046
# 132
# 50
# Total charge 5296.844745901703
# Standard deviation 86.28252290750972
# Maximum corrected charge observed 357.5994627560744
# Mean corrected charge observed 105.93689491803407
# Ratio 3.3755894302240756
# 129
# 37
# Total charge 3208.8452973444796
# Standard deviation 79.43210384165418
# Maximum corrected charge observed 368.58837263533536
# Mean corrected charge observed 86.72554857687783
# Ratio 4.250055245353685
# 172
# 25
# Total charge 3197.8178023873725
# Standard deviation 101.10144446581647
# Maximum corrected charge observed 419.3913887818656
# Mean corrected charge observed 127.9127120954949
# Ratio 3.2787311121099796
# 129
# 30
# Total charge 2750.7449751570284
# Standard deviation 66.28349200245204
# Maximum corrected charge observed 229.8333589200922
# Mean corrected charge observed 91.69149917190094
# Ratio 2.5065939699514166
# 128
# 47
# Total charge 8320.597471050038
# Standard deviation 116.0303180518894
# Maximum corrected charge observed 600.7648936949065
# Mean corrected charge observed 177.0339887457455
# Ratio 3.3935002987348337
# 127
# 24
# Total charge 2267.4688223711046
# Standard deviation 68.2959126549167
# Maximum corrected charge observed 309.5136082102704
# Mean corrected charge observed 94.47786759879602
# Ratio 3.276043544130696
# 132
# 22
# Total charge 2431.359942233773
# Standard deviation 84.9441519864057
# Maximum corrected charge observed 366.85023969242775
# Mean corrected charge observed 110.51636101062604
# Ratio 3.3194201866378448
# 129
# 79
# Total charge 8824.739095248748
# Standard deviation 74.82642441533022
# Maximum corrected charge observed 402.6559087622343
# Mean corrected charge observed 111.70555816770566
# Ratio 3.6046183857540854
# 126
# 21
# Total charge 2364.337287158292
# Standard deviation 91.88467193806075
# Maximum corrected charge observed 385.5795908559351
# Mean corrected charge observed 112.58748986468056
# Ratio 3.4247107855354537
# 131
# 13
# Total charge 1507.6584100977075
# Standard deviation 44.277038500016765
# Maximum corrected charge observed 176.72160069636357
# Mean corrected charge observed 115.97372385366981
# Ratio 1.5238072455045297
# 129
# 34
# Total charge 3728.871608024995
# Standard deviation 114.74242393958646
# Maximum corrected charge observed 613.5264006308664
# Mean corrected charge observed 109.67269435367632
# Ratio 5.594158183552463
# 147
# 14
# Total charge 881.90600057961
# Standard deviation 45.33626160457375
# Maximum corrected charge observed 195.6660976478979
# Mean corrected charge observed 62.99328575568643
# Ratio 3.1061421118239583
# 127
# 56
# Total charge 30930.931998203992
# Standard deviation 843.0255495460349
# Maximum corrected charge observed 5329.267035102428
# Mean corrected charge observed 552.3380713964999
# Ratio 9.648560023444002
# 127
# 18
# Total charge 1745.7435509376105
# Standard deviation 75.02418989107834
# Maximum corrected charge observed 247.53367024870576
# Mean corrected charge observed 96.98575282986725
# Ratio 2.5522683799024604
# 130
# 23
# Total charge 18575.541364752673
# Standard deviation 878.1737781720508
# Maximum corrected charge observed 4237.146436234495
# Mean corrected charge observed 807.6322332501162
# Ratio 5.246381040517845
# 129
# 72
# Total charge 8412.22289261276
# Standard deviation 81.96004393665731
# Maximum corrected charge observed 399.41332919947376
# Mean corrected charge observed 116.8364290640661
# Ratio 3.4185684413588113
# 129
# 89
# Total charge 8997.635972696104
# Standard deviation 66.63246532057707
# Maximum corrected charge observed 338.47096211461616
# Mean corrected charge observed 101.09703340107981
# Ratio 3.3479811496723992
# 132
# 14
# Total charge 1023.6978421455738
# Standard deviation 40.862056894487054
# Maximum corrected charge observed 151.64075909713506
# Mean corrected charge observed 73.12127443896955
# Ratio 2.073825439458137
# 130
# 23
# Total charge 1787.1219651533302
# Standard deviation 64.04526237611206
# Maximum corrected charge observed 304.05448177322603
# Mean corrected charge observed 77.70095500666653
# Ratio 3.913136997442811
# 128
# 30
# Total charge 3079.0134148056363
# Standard deviation 78.97961320006253
# Maximum corrected charge observed 343.59953713002943
# Mean corrected charge observed 102.63378049352121
# Ratio 3.347821111897162
# 129
# 44
# Total charge 5598.258525423865
# Standard deviation 87.19041108625137
# Maximum corrected charge observed 395.3275502580625
# Mean corrected charge observed 127.23314830508784
# Ratio 3.1071112797595846
# 129
# 39
# Total charge 4816.920586671444
# Standard deviation 79.13695714853418
# Maximum corrected charge observed 341.46822651328114
# Mean corrected charge observed 123.51078427362677
# Ratio 2.764683493198373
# 127
# 36
# Total charge 5223.930626433092
# Standard deviation 102.56625981145197
# Maximum corrected charge observed 397.1463881783093
# Mean corrected charge observed 145.1091840675859
# Ratio 2.7368797552698996
# 132
# 44
# Total charge 5735.900617275349
# Standard deviation 89.96797838301498
# Maximum corrected charge observed 499.7822267024684
# Mean corrected charge observed 130.36137766534884
# Ratio 3.8338213023911205
# 126
# 12
# Total charge 1130.767273367926
# Standard deviation 76.29050003963104
# Maximum corrected charge observed 237.34017858914757
# Mean corrected charge observed 94.23060611399383
# Ratio 2.5187164593001707
# 133
# 14
# Total charge 690.2841788906205
# Standard deviation 26.59618797368824
# Maximum corrected charge observed 103.98534734918944
# Mean corrected charge observed 49.306012777901465
# Ratio 2.1089790370515376
# 129
# 42
# Total charge 7108.355600846056
# Standard deviation 202.6935062880764
# Maximum corrected charge observed 1333.8101762133551
# Mean corrected charge observed 169.2465619249061
# Ratio 7.8808701402463965
# 133
# 56
# Total charge 22263.543198632433
# Standard deviation 452.9269494333526
# Maximum corrected charge observed 2636.434838414585
# Mean corrected charge observed 397.5632714041506
# Ratio 6.631484918370305
# 150
# 101
# Total charge 11134.90785200671
# Standard deviation 81.16756389693039
# Maximum corrected charge observed 530.759515094157
# Mean corrected charge observed 110.24661239610604
# Ratio 4.814293188322072
# 148
# 22
# Total charge 2012.0175684426029
# Standard deviation 81.32340431426809
# Maximum corrected charge observed 381.63752646624863
# Mean corrected charge observed 91.45534402011832
# Ratio 4.172938504088904
# 126
# 24
# Total charge 2285.9372706430586
# Standard deviation 58.56181088781967
# Maximum corrected charge observed 230.8203870161755
# Mean corrected charge observed 95.2473862767941
# Ratio 2.423377648866908
# 128
# 26
# Total charge 2466.064446943763
# Standard deviation 66.3971261456701
# Maximum corrected charge observed 273.6359053093746
# Mean corrected charge observed 94.84863257476012
# Ratio 2.8849747000168247
# 129
# 21
# Total charge 1626.0736514547777
# Standard deviation 65.16143331880669
# Maximum corrected charge observed 252.52466188042342
# Mean corrected charge observed 77.43207864070371
# Ratio 3.261240900585598
# 128
# 42
# Total charge 5924.478961514288
# Standard deviation 98.15598654499024
# Maximum corrected charge observed 407.77855871095613
# Mean corrected charge observed 141.05902289319732
# Ratio 2.890836405549932
# 127
# 17
# Total charge 1781.6309570780318
# Standard deviation 63.13450328850844
# Maximum corrected charge observed 261.6688695990643
# Mean corrected charge observed 104.80182100459011
# Ratio 2.4967969744304703
# 132
# 35
# Total charge 3367.5931807284583
# Standard deviation 84.27370133969585
# Maximum corrected charge observed 402.72091594118154
# Mean corrected charge observed 96.21694802081309
# Ratio 4.185550718716076
# 128
# 29
# Total charge 3335.4521070404307
# Standard deviation 80.42926227436384
# Maximum corrected charge observed 377.4987217470189
# Mean corrected charge observed 115.01558989794589
# Ratio 3.2821526375857055
# 172
# 31
# Total charge 2583.374342071214
# Standard deviation 61.065049533577216
# Maximum corrected charge observed 260.6944737405558
# Mean corrected charge observed 83.33465619584561
# Ratio 3.12828402541069
# 129
# 32
# Total charge 3115.2982720894483
# Standard deviation 73.07756554848537
# Maximum corrected charge observed 311.2252298691254
# Mean corrected charge observed 97.35307100279526
# Ratio 3.1968712097452925
# 147
# 23
# Total charge 4057.167780417638
# Standard deviation 152.05318239544872
# Maximum corrected charge observed 736.6974342733736
# Mean corrected charge observed 176.39859914859295
# Ratio 4.176322475513547
# 129
# 36
# Total charge 3797.9936634596343
# Standard deviation 71.8940943081709
# Maximum corrected charge observed 260.3437132451917
# Mean corrected charge observed 105.49982398498985
# Ratio 2.4677170388666476
# 129
# 48
# Total charge 7226.186389037105
# Standard deviation 96.37319757966135
# Maximum corrected charge observed 590.7804940754409
# Mean corrected charge observed 150.54554977160635
# Ratio 3.9242640846688452
# 129
# 33
# Total charge 4674.337995070011
# Standard deviation 104.35521468533273
# Maximum corrected charge observed 510.69214167128484
# Mean corrected charge observed 141.64660591121245
# Ratio 3.6053962492500466
# 129
# 39
# Total charge 4100.520304316232
# Standard deviation 67.93918213192966
# Maximum corrected charge observed 319.13185263908264
# Mean corrected charge observed 105.14154626451877
# Ratio 3.035259266933355
# 147
# 44
# Total charge 26881.832863498596
# Standard deviation 1245.915244571025
# Maximum corrected charge observed 7565.538361955351
# Mean corrected charge observed 610.9507468976954
# Ratio 12.383221397750763
# 129
# 91
# Total charge 13283.380458119538
# Standard deviation 95.88833736040536
# Maximum corrected charge observed 570.9353569424431
# Mean corrected charge observed 145.97121382548943
# Ratio 3.9112873146687956
# 154
# 115
# Total charge 22374.85932715216
# Standard deviation 133.71647538356484
# Maximum corrected charge observed 740.9996639164272
# Mean corrected charge observed 194.5639941491492
# Ratio 3.8085138370894582
# 129
# 35
# Total charge 4483.464817732944
# Standard deviation 161.02052183540223
# Maximum corrected charge observed 905.9696169462367
# Mean corrected charge observed 128.0989947923698
# Ratio 7.07241784695254
# 133
# 61
# Total charge 6974.257266254887
# Standard deviation 62.761253850493375
# Maximum corrected charge observed 307.23731423792924
# Mean corrected charge observed 114.33208633204734
# Ratio 2.68723613899286
# 127
# 30
# Total charge 3471.101951443971
# Standard deviation 64.32137327590729
# Maximum corrected charge observed 247.39349698591172
# Mean corrected charge observed 115.70339838146569
# Ratio 2.1381696687099314
# 129
# 66
# Total charge 8189.387931944591
# Standard deviation 79.6721073108403
# Maximum corrected charge observed 401.80256854081165
# Mean corrected charge observed 124.0816353324938
# Ratio 3.238211419958533
# 133
# 85
# Total charge 9547.123884585222
# Standard deviation 78.6194637906605
# Maximum corrected charge observed 427.63449535283127
# Mean corrected charge observed 112.31910452453202
# Ratio 3.807317527709011
# 149
# 47
# Total charge 6564.877532723999
# Standard deviation 99.6730583489443
# Maximum corrected charge observed 540.8720617674962
# Mean corrected charge observed 139.67824537710638
# Ratio 3.872271306868425
# 126
# 19
# Total charge 1368.2209703321146
# Standard deviation 45.512835918804996
# Maximum corrected charge observed 220.11508866803044
# Mean corrected charge observed 72.01163001747972
# Ratio 3.056660272994805
# 128
# 69
# Total charge 62668.70238390018
# Standard deviation 622.7263087233686
# Maximum corrected charge observed 3289.913066315115
# Mean corrected charge observed 908.2420635347852
# Ratio 3.622286611028683
# 128
# 41
# Total charge 4439.625056358586
# Standard deviation 81.07466385669696
# Maximum corrected charge observed 493.17713067335467
# Mean corrected charge observed 108.28353795996551
# Ratio 4.554497756211952
# 149
# 24
# Total charge 2186.9833379482416
# Standard deviation 71.81706105191326
# Maximum corrected charge observed 247.56306951572708
# Mean corrected charge observed 91.1243057478434
# Ratio 2.7167622017420534
# 173
# 37
# Total charge 4311.142453618186
# Standard deviation 84.61830569539403
# Maximum corrected charge observed 349.58601670704405
# Mean corrected charge observed 116.51736361130232
# Ratio 3.000291165814996
# 129
# 63
# Total charge 8745.931813580357
# Standard deviation 181.26116749881353
# Maximum corrected charge observed 1054.1384490289754
# Mean corrected charge observed 138.8243145012755
# Ratio 7.593327241095724
# 129
# 47
# Total charge 6074.8711054453015
# Standard deviation 107.81875819900459
# Maximum corrected charge observed 501.67547841401887
# Mean corrected charge observed 129.25257671160216
# Ratio 3.8813576578314106
# 129
# 62
# Total charge 7397.504512454823
# Standard deviation 75.74560944311055
# Maximum corrected charge observed 410.56285492199976
# Mean corrected charge observed 119.31458891056167
# Ratio 3.4410113521805625
# 126
# 17
# Total charge 23009.678060625058
# Standard deviation 727.545199887518
# Maximum corrected charge observed 3280.1167581983987
# Mean corrected charge observed 1353.510474154415
# Ratio 2.4234143886087036
# 146
# 60
# Total charge 6663.8117996883275
# Standard deviation 85.65616360645058
# Maximum corrected charge observed 449.5466707726196
# Mean corrected charge observed 111.06352999480546
# Ratio 4.047653363742763
# 125
# 7
# Total charge 434.25663305712845
# Standard deviation 49.484297897836804
# Maximum corrected charge observed 178.24961365982458
# Mean corrected charge observed 62.03666186530406
# Ratio 2.873294730893898
# 127
# 15
# Total charge 1517.473582457203
# Standard deviation 76.62184098737414
# Maximum corrected charge observed 252.6335156164367
# Mean corrected charge observed 101.16490549714688
# Ratio 2.4972446163512867
# 129
# 54
# Total charge 5005.435591951377
# Standard deviation 64.97814999061058
# Maximum corrected charge observed 315.75126518564264
# Mean corrected charge observed 92.69325170280328
# Ratio 3.4064104925137015
# 129
# 36
# Total charge 16699.96709205345
# Standard deviation 297.21784656906783
# Maximum corrected charge observed 1223.599106861687
# Mean corrected charge observed 463.88797477926255
# Ratio 2.637703871163996
# 128
# 39
# Total charge 4546.150422126299
# Standard deviation 90.12005650215882
# Maximum corrected charge observed 351.92389816431364
# Mean corrected charge observed 116.56795954169999
# Ratio 3.019044852015442
# 128
# 25
# Total charge 2943.049314616512
# Standard deviation 94.47945944479812
# Maximum corrected charge observed 404.81843079274137
# Mean corrected charge observed 117.72197258466049
# Ratio 3.43876696851655
# 147
# 37
# Total charge 3534.9732437343523
# Standard deviation 93.24860900582043
# Maximum corrected charge observed 561.4382052815843
# Mean corrected charge observed 95.53981739822574
# Ratio 5.876483968369095
# 129
# 167
# Total charge 26407.949885812297
# Standard deviation 106.54236520268384
# Maximum corrected charge observed 558.4876013103051
# Mean corrected charge observed 158.1314364419898
# Ratio 3.5317936387378936
# 149
# 30
# Total charge 1928.4320842720545
# Standard deviation 71.34026797984971
# Maximum corrected charge observed 379.3847435688655
# Mean corrected charge observed 64.28106947573515
# Ratio 5.901966887966539
# 127
# 37
# Total charge 2909.4301223661723
# Standard deviation 59.82335162805968
# Maximum corrected charge observed 273.0925446597922
# Mean corrected charge observed 78.6332465504371
# Ratio 3.4729908358117285
# 130
# 26
# Total charge 2502.327077485167
# Standard deviation 54.705161925191454
# Maximum corrected charge observed 235.72284922025955
# Mean corrected charge observed 96.24334913404489
# Ratio 2.449237805429565
# 131
# 22
# Total charge 2483.3536504881245
# Standard deviation 73.68624657755173
# Maximum corrected charge observed 261.480005254974
# Mean corrected charge observed 112.87971138582384
# Ratio 2.316448208848028
# 133
# 72
# Total charge 123714.62810903671
# Standard deviation 1835.9584145178235
# Maximum corrected charge observed 14177.880609363052
# Mean corrected charge observed 1718.258723736621
# Ratio 8.2513072178857
# 133
# 92
# Total charge 15298.858441376282
# Standard deviation 164.8654629909944
# Maximum corrected charge observed 1365.7321306598876
# Mean corrected charge observed 166.29193958017697
# Ratio 8.212858266659435
# 127
# 23
# Total charge 1760.168773220543
# Standard deviation 54.237215888248045
# Maximum corrected charge observed 261.66939307479413
# Mean corrected charge observed 76.52907709654535
# Ratio 3.419215323146845
# 128
# 27
# Total charge 2984.6889546215525
# Standard deviation 88.93766747926966
# Maximum corrected charge observed 425.7223586571674
# Mean corrected charge observed 110.5440353563538
# Ratio 3.8511563042256705
# 128
# 25
# Total charge 2760.7374412503486
# Standard deviation 67.37942433786678
# Maximum corrected charge observed 279.4129353647853
# Mean corrected charge observed 110.42949765001394
# Ratio 2.530238218146508
# 133
# 132
# Total charge 16538.212281766977
# Standard deviation 83.54340482864545
# Maximum corrected charge observed 549.4862290847987
# Mean corrected charge observed 125.28948698308317
# Ratio 4.385732931917834
# 129
# 33
# Total charge 44583.47718321899
# Standard deviation 924.4090536483438
# Maximum corrected charge observed 5225.220162024165
# Mean corrected charge observed 1351.014460097545
# Ratio 3.8676271175120487
# 132
# 22
# Total charge 1993.3060524715233
# Standard deviation 53.67184093961734
# Maximum corrected charge observed 266.97753355496974
# Mean corrected charge observed 90.60482056688743
# Ratio 2.9466151125797797
# 124
# 7
# Total charge 589.2201759997918
# Standard deviation 26.41526612782656
# Maximum corrected charge observed 132.74677657695352
# Mean corrected charge observed 84.17431085711311
# Ratio 1.5770461940851852
# 149
# 20
# Total charge 2438.950198951075
# Standard deviation 82.19765090349776
# Maximum corrected charge observed 349.0705825332681
# Mean corrected charge observed 121.94750994755375
# Ratio 2.862465848490008
# 128
# 23
# Total charge 3600.5681611218056
# Standard deviation 108.61634343119567
# Maximum corrected charge observed 446.61877519137994
# Mean corrected charge observed 156.5464417879046
# Ratio 2.852947470990602
# 149
# 18
# Total charge 10900.889364109
# Standard deviation 316.4144493881333
# Maximum corrected charge observed 1219.8118882230958
# Mean corrected charge observed 605.6049646727222
# Ratio 2.0142039107659895
# 129
# 49
# Total charge 34260.91970717665
# Standard deviation 484.89836368711246
# Maximum corrected charge observed 2709.515884639879
# Mean corrected charge observed 699.202443003605
# Ratio 3.875152199126268
# 149
# 46
# Total charge 6504.626470599684
# Standard deviation 115.73172945416408
# Maximum corrected charge observed 655.5078124431511
# Mean corrected charge observed 141.40492327390618
# Ratio 4.635678852379207
# 130
# 28
# Total charge 18188.59821178821
# Standard deviation 690.7236116485034
# Maximum corrected charge observed 3551.7077458014123
# Mean corrected charge observed 649.5927932781503
# Ratio 5.467591054817322
# 128
# 46
# Total charge 4380.715499421182
# Standard deviation 54.419162652013156
# Maximum corrected charge observed 270.3351995765374
# Mean corrected charge observed 95.23294563959092
# Ratio 2.8386730848336974
# 129
# 60
# Total charge 8092.9626266768755
# Standard deviation 95.48774728505917
# Maximum corrected charge observed 537.4054555457169
# Mean corrected charge observed 134.8827104446146
# Ratio 3.9842427081592926
# 126
# 15
# Total charge 24202.13886583148
# Standard deviation 871.742126707506
# Maximum corrected charge observed 4448.317331603917
# Mean corrected charge observed 1613.4759243887652
# Ratio 2.756977816876368
# 131
# 22
# Total charge 1535.9133243850893
# Standard deviation 45.88221331396872
# Maximum corrected charge observed 170.46907933491337
# Mean corrected charge observed 69.81424201750406
# Ratio 2.4417522042590223
# 132
# 48
# Total charge 5160.548235852834
# Standard deviation 75.90706945518541
# Maximum corrected charge observed 373.3558075523107
# Mean corrected charge observed 107.51142158026738
# Ratio 3.4727083138191555
# 132
# 25
# Total charge 2245.733081030433
# Standard deviation 83.99705350637598
# Maximum corrected charge observed 374.2896071879564
# Mean corrected charge observed 89.82932324121731
# Ratio 4.166675131046932
# 126
# 23
# Total charge 3374.0404715608743
# Standard deviation 116.06955471009353
# Maximum corrected charge observed 502.25900328674715
# Mean corrected charge observed 146.69741180699452
# Ratio 3.423775492014505
# 129
# 25
# Total charge 1653.0537743056725
# Standard deviation 56.38556818563486
# Maximum corrected charge observed 281.0281141233706
# Mean corrected charge observed 66.1221509722269
# Ratio 4.250135695697649
# 132
# 31
# Total charge 5689.3804324013245
# Standard deviation 144.86955669584611
# Maximum corrected charge observed 523.537228103083
# Mean corrected charge observed 183.52840104520402
# Ratio 2.8526224013368533
# 127
# 39
# Total charge 3899.1650755185406
# Standard deviation 64.74123728821755
# Maximum corrected charge observed 299.41980559684026
# Mean corrected charge observed 99.97859167996258
# Ratio 2.9948392007291007
# 129
# 94
# Total charge 10241.502645648774
# Standard deviation 71.1535297135105
# Maximum corrected charge observed 340.7223157593381
# Mean corrected charge observed 108.9521558047742
# Ratio 3.127265479444583
# 133
# 56
# Total charge 6829.769455744708
# Standard deviation 96.40515149674307
# Maximum corrected charge observed 574.9242523073584
# Mean corrected charge observed 121.96016885258406
# Ratio 4.714032931540805
# 127
# 16
# Total charge 2124.5433462369465
# Standard deviation 78.85753596061295
# Maximum corrected charge observed 261.27712117147087
# Mean corrected charge observed 132.78395913980916
# Ratio 1.967685877601905
# 129
# 50
# Total charge 6417.784616471701
# Standard deviation 77.60796177374
# Maximum corrected charge observed 355.3692379879245
# Mean corrected charge observed 128.35569232943402
# Ratio 2.7686285784337796
# 133
# 87
# Total charge 10096.558113087607
# Standard deviation 84.33137530730824
# Maximum corrected charge observed 433.885167021838
# Mean corrected charge observed 116.05239210445525
# Ratio 3.7387007639731467
# 129
# 101
# Total charge 37272.551507853976
# Standard deviation 659.8890438470668
# Maximum corrected charge observed 2911.335939691421
# Mean corrected charge observed 369.03516344409877
# Ratio 7.889047516558483
# 128
# 55
# Total charge 24754.776406340825
# Standard deviation 427.83555415135896
# Maximum corrected charge observed 1772.7653849790145
# Mean corrected charge observed 450.0868437516514
# Ratio 3.938718515303215
# 128
# 33
# Total charge 4166.777845832306
# Standard deviation 83.82320795661943
# Maximum corrected charge observed 396.97826591190193
# Mean corrected charge observed 126.2659953282517
# Ratio 3.1439839750986307
# 129
# 38
# Total charge 6226.558211492941
# Standard deviation 243.88104168755987
# Maximum corrected charge observed 1428.4421406368217
# Mean corrected charge observed 163.85679503928793
# Ratio 8.717625291611032
# 128
# 46
# Total charge 5814.655492043156
# Standard deviation 84.98698602344088
# Maximum corrected charge observed 394.7108660061658
# Mean corrected charge observed 126.40555417485122
# Ratio 3.1225753376325516
# 129
# 42
# Total charge 5784.172000516283
# Standard deviation 84.7412864656328
# Maximum corrected charge observed 372.1733794267189
# Mean corrected charge observed 137.7183809646734
# Ratio 2.702423429753987
# 147
# 17
# Total charge 1560.2846632374694
# Standard deviation 42.62552666864446
# Maximum corrected charge observed 173.2889625708662
# Mean corrected charge observed 91.78145077867467
# Ratio 1.888060834740365
# 127
# 53
# Total charge 9273.864980991544
# Standard deviation 296.3182900664103
# Maximum corrected charge observed 1842.4986477819893
# Mean corrected charge observed 174.97858454701026
# Ratio 10.529852281934412
# 129
# 109
# Total charge 13475.103190271377
# Standard deviation 84.54575300174211
# Maximum corrected charge observed 523.9191816861653
# Mean corrected charge observed 123.62479991074657
# Ratio 4.237977995227651
# 133
# 41
# Total charge 2795.4052418990404
# Standard deviation 44.91747328645651
# Maximum corrected charge observed 186.1520305375355
# Mean corrected charge observed 68.18061565607415
# Ratio 2.7302779352499345
# 129
# 48
# Total charge 5415.0484617919465
# Standard deviation 86.22642572937487
# Maximum corrected charge observed 373.57864508292454
# Mean corrected charge observed 112.81350962066556
# Ratio 3.3114708188680546
# 129
# 64
# Total charge 19062.03888756471
# Standard deviation 186.8740036823915
# Maximum corrected charge observed 994.2215868435125
# Mean corrected charge observed 297.8443576181986
# Ratio 3.3380574834255796
# 129
# 78
# Total charge 6524.480590794345
# Standard deviation 70.98665585715243
# Maximum corrected charge observed 465.0293950100355
# Mean corrected charge observed 83.64718706146596
# Ratio 5.5594146240485145
# 126
# 19
# Total charge 30161.128675391104
# Standard deviation 712.1719733862841
# Maximum corrected charge observed 2916.6125550073957
# Mean corrected charge observed 1587.4278250205844
# Ratio 1.8373197880474192
# 149
# 43
# Total charge 5453.743496632169
# Standard deviation 95.49001177129598
# Maximum corrected charge observed 466.55872305540936
# Mean corrected charge observed 126.83124410772486
# Ratio 3.6785787787363735
# 132
# 13
# Total charge 678.0835256300785
# Standard deviation 36.662099534458875
# Maximum corrected charge observed 120.3454801700528
# Mean corrected charge observed 52.16027120231373
# Ratio 2.3072249701936847
# 129
# 32
# Total charge 3995.3552783161103
# Standard deviation 52.83965267555273
# Maximum corrected charge observed 252.1399322176384
# Mean corrected charge observed 124.85485244737845
# Ratio 2.019464420286795
# 128
# 26
# Total charge 1314.6206984215887
# Standard deviation 37.093796622037374
# Maximum corrected charge observed 154.99822953395218
# Mean corrected charge observed 50.56233455467649
# Ratio 3.0654879941578264
# 129
# 55
# Total charge 5930.560182282535
# Standard deviation 75.5802746400631
# Maximum corrected charge observed 312.9004453255282
# Mean corrected charge observed 107.82836695059154
# Ratio 2.901837931653955
# 149
# 80
# Total charge 9170.104737608872
# Standard deviation 73.39512284709471
# Maximum corrected charge observed 372.5997631875325
# Mean corrected charge observed 114.6263092201109
# Ratio 3.2505605887741593
# 128
# 32
# Total charge 20306.980981091096
# Standard deviation 434.34379166124427
# Maximum corrected charge observed 2036.8057729536813
# Mean corrected charge observed 634.5931556590967
# Ratio 3.209624552030077
# 128
# 6
# Total charge 421.1056597319441
# Standard deviation 53.86307903362787
# Maximum corrected charge observed 185.72587687669667
# Mean corrected charge observed 70.18427662199069
# Ratio 2.6462604705183153
# 129
# 63
# Total charge 7857.765451581055
# Standard deviation 100.76262497804937
# Maximum corrected charge observed 472.50354772775006
# Mean corrected charge observed 124.72643573938181
# Ratio 3.7883191716875078
# 148
# 16
# Total charge 1840.4723438064984
# Standard deviation 62.24986923617393
# Maximum corrected charge observed 246.84750626379227
# Mean corrected charge observed 115.02952148790615
# Ratio 2.1459491708808427
# 132
# 36
# Total charge 5005.081773858507
# Standard deviation 95.79999357882465
# Maximum corrected charge observed 390.6431853023456
# Mean corrected charge observed 139.03004927384742
# Ratio 2.809775205739127
# 131
# 29
# Total charge 2477.7206809028253
# Standard deviation 67.111049033553
# Maximum corrected charge observed 253.29261580268954
# Mean corrected charge observed 85.43864416906294
# Ratio 2.96461417741465
# 127
# 33
# Total charge 4476.575479622303
# Standard deviation 186.9037746999869
# Maximum corrected charge observed 1108.3304857928374
# Mean corrected charge observed 135.65380241279706
# Ratio 8.170286907403945
# 127
# 29
# Total charge 2712.069059981408
# Standard deviation 69.41402572349817
# Maximum corrected charge observed 348.61914349593224
# Mean corrected charge observed 93.51962275797959
# Ratio 3.72776464676432
# 129
# 70
# Total charge 76591.35150720511
# Standard deviation 979.3812892273141
# Maximum corrected charge observed 5103.619885862737
# Mean corrected charge observed 1094.1621643886444
# Ratio 4.664409035487303
# 132
# 21
# Total charge 2946.9329125812974
# Standard deviation 114.33354081961674
# Maximum corrected charge observed 511.41406862354154
# Mean corrected charge observed 140.33013869434748
# Ratio 3.6443637366984327
# 128
# 27
# Total charge 2820.663537784944
# Standard deviation 90.0743104135185
# Maximum corrected charge observed 366.6399023764105
# Mean corrected charge observed 104.46901991796088
# Ratio 3.5095562556663342
# 126
# 20
# Total charge 1681.0516597745852
# Standard deviation 55.19346534517777
# Maximum corrected charge observed 209.5052042335939
# Mean corrected charge observed 84.05258298872926
# Ratio 2.492549268375093
# 129
# 45
# Total charge 5291.2336062197
# Standard deviation 80.30264862388253
# Maximum corrected charge observed 438.47151797425073
# Mean corrected charge observed 117.58296902710444
# Ratio 3.729039346448015
# 131
# 22
# Total charge 1550.2646289992763
# Standard deviation 53.45935893726203
# Maximum corrected charge observed 229.94309182046817
# Mean corrected charge observed 70.46657404542165
# Ratio 3.263151287477811
# 129
# 31
# Total charge 3332.3577386200886
# Standard deviation 69.90739839132553
# Maximum corrected charge observed 257.7977005861121
# Mean corrected charge observed 107.49541092322866
# Ratio 2.3982205228298232
# 129
# 100
# Total charge 8936.837366424548
# Standard deviation 70.31867820363904
# Maximum corrected charge observed 390.6446728851792
# Mean corrected charge observed 89.36837366424548
# Ratio 4.371173569218351
# 128
# 25
# Total charge 2075.842352293531
# Standard deviation 54.87493436390318
# Maximum corrected charge observed 243.23819854808394
# Mean corrected charge observed 83.03369409174124
# Ratio 2.929391510382977
# 127
# 34
# Total charge 18568.35940075367
# Standard deviation 272.8328577755233
# Maximum corrected charge observed 1183.0590130667001
# Mean corrected charge observed 546.1282176692256
# Ratio 2.166266043010518
# 133
# 33
# Total charge 3703.1334331064013
# Standard deviation 88.00213693002168
# Maximum corrected charge observed 408.86019049746074
# Mean corrected charge observed 112.21616463958792
# Ratio 3.643505298997021
# 129
# 77
# Total charge 61704.266584358906
# Standard deviation 840.4213933452191
# Maximum corrected charge observed 5295.10502292063
# Mean corrected charge observed 801.3541114851806
# Ratio 6.60769683093908
# 132
# 94
# Total charge 10174.045395782805
# Standard deviation 73.24843744753483
# Maximum corrected charge observed 355.09633302929063
# Mean corrected charge observed 108.23452548705112
# Ratio 3.2808046363336567
# 127
# 16
# Total charge 1208.036209279593
# Standard deviation 32.40600612556483
# Maximum corrected charge observed 141.14132402224672
# Mean corrected charge observed 75.50226307997457
# Ratio 1.8693654768035897
# 129
# 24
# Total charge 2396.347402550854
# Standard deviation 77.08040622481926
# Maximum corrected charge observed 296.6288090831391
# Mean corrected charge observed 99.84780843961892
# Ratio 2.97080941203151
# 147
# 48
# Total charge 5301.181781558702
# Standard deviation 70.00801464526346
# Maximum corrected charge observed 323.3055427640787
# Mean corrected charge observed 110.44128711580629
# Ratio 2.927397454405504
# 129
# 39
# Total charge 58533.683775770565
# Standard deviation 1592.1492586137056
# Maximum corrected charge observed 7578.9623434612695
# Mean corrected charge observed 1500.8636865582196
# Ratio 5.049733970738772
# 128
# 77
# Total charge 8183.27770336257
# Standard deviation 109.35460791026014
# Maximum corrected charge observed 847.246553484332
# Mean corrected charge observed 106.2763338099035
# Ratio 7.972109340916878
# 127
# 61
# Total charge 9319.163691057534
# Standard deviation 120.08192294868627
# Maximum corrected charge observed 628.7759452030948
# Mean corrected charge observed 152.77317526323827
# Ratio 4.1157483577838345
# 128
# 65
# Total charge 5572.440726230698
# Standard deviation 62.49883284006319
# Maximum corrected charge observed 343.18741744422897
# Mean corrected charge observed 85.72985732662612
# Ratio 4.003125960383947
# 149
# 43
# Total charge 5603.353899125192
# Standard deviation 93.23982918013057
# Maximum corrected charge observed 446.3224407954869
# Mean corrected charge observed 130.3105557936091
# Ratio 3.4250674327748984
# 131
# 18
# Total charge 1337.3598101021344
# Standard deviation 56.320658549058756
# Maximum corrected charge observed 215.71357746447967
# Mean corrected charge observed 74.29776722789636
# Ratio 2.9033655453307667
# 129
# 89
# Total charge 14391.67680250269
# Standard deviation 97.07365215976432
# Maximum corrected charge observed 569.9237584825654
# Mean corrected charge observed 161.7042337359853
# Ratio 3.524482602063967
# 215
# 57
# Total charge 44572.93677914177
# Standard deviation 521.3611059207558
# Maximum corrected charge observed 3711.8057914325323
# Mean corrected charge observed 781.9813470024872
# ...
# Ratio 3.1443078361828225
# 133
# 76
# Total charge 9024.756833935458
# Standard deviation 102.57076882417107
# Maximum corrected charge observed 672.8545317937746
# Mean corrected charge observed 118.74680044651919
# Ratio 5.666296096094082
# 128
# 13
# Total charge 750.1492651064807
# Standard deviation 35.290687869261674
# Maximum corrected charge observed 136.92911269135976
# Mean corrected charge observed 57.70378962357544
# Ratio 2.372965685349304
# 128
# 100
# Total charge 10669.83841719884
# Standard deviation 68.86217861715103
# Maximum corrected charge observed 388.1052290293662
# Mean corrected charge observed 106.6983841719884
# Ratio 3.637404933928285
# 132
# 29
# Total charge 2857.237835805768
# Standard deviation 70.24053532024881
# Maximum corrected charge observed 325.5819902471318
# Mean corrected charge observed 98.525442613992
# Ratio 3.3045473494873145
# 130
# 20
# Total charge 1091.9994078370962
# Standard deviation 39.59111721131073
# Maximum corrected charge observed 156.91768573792382
# Mean corrected charge observed 54.59997039185481
# Ratio 2.873951846708926
# 128
# 18
# Total charge 2201.488876187443
# Standard deviation 139.403589903725
# Maximum corrected charge observed 659.3140149820135
# Mean corrected charge observed 122.30493756596906
# Ratio 5.390739148420656
# 133
# 22
# Total charge 1711.1669754642514
# Standard deviation 59.54705006584242
# Maximum corrected charge observed 257.48915120444497
# Mean corrected charge observed 77.78031706655689
# Ratio 3.310466721087169
# 129
# 29
# Total charge 1807.9855800429768
# Standard deviation 39.10896557524712
# Maximum corrected charge observed 180.44726912028023
# Mean corrected charge observed 62.34433034630955
# Ratio 2.8943653435353927
# 133
# 73
# Total charge 9773.306157778383
# Standard deviation 91.58958540401058
# Maximum corrected charge observed 375.667569074892
# Mean corrected charge observed 133.88090627093675
# Ratio 2.8059831647288678
# 165
# 94
# Total charge 44970.35644874624
# Standard deviation 1716.7736499159137
# Maximum corrected charge observed 15331.840099902822
# Mean corrected charge observed 478.4080473270877
# Ratio 32.047621660135746
# 129
# 64
# Total charge 9790.402471875197
# Standard deviation 97.38294925195095
# Maximum corrected charge observed 398.12295585978563
# Mean corrected charge observed 152.97503862304995
# Ratio 2.602535416518583
# 133
# 147
# Total charge 86989.9026181236
# Standard deviation 620.7235764264344
# Maximum corrected charge observed 5013.883478271135
# Mean corrected charge observed 591.768045021249
# Ratio 8.472717512300108
# 129
# 52
# Total charge 5154.157078310702
# Standard deviation 69.67661107082873
# Maximum corrected charge observed 298.34374699273485
# Mean corrected charge observed 99.11840535212887
# Ratio 3.009973232850512
# 130
# 10
# Total charge 3455.8311113476548
# Standard deviation 532.9285187185909
# Maximum corrected charge observed 1799.9205042927938
# Mean corrected charge observed 345.5831111347655
# Ratio 5.208357834335507
# 131
# 23
# Total charge 2507.333940848084
# Standard deviation 89.07694013919823
# Maximum corrected charge observed 422.88639284185956
# Mean corrected charge observed 109.014519167308
# Ratio 3.8791749582717747
# 128
# 69
# Total charge 7786.866449656451
# Standard deviation 68.11596906725289
# Maximum corrected charge observed 345.59455294302114
# Mean corrected charge observed 112.85313695154277
# Ratio 3.0623389147916518
# 127
# 13
# Total charge 1217.6453184619986
# Standard deviation 66.2661896628222
# Maximum corrected charge observed 227.74933538914115
# Mean corrected charge observed 93.66502449707681
# Ratio 2.4315301961646205
# 129
# 38
# Total charge 4652.6832620841205
# Standard deviation 93.95401158403679
# Maximum corrected charge observed 423.6288518243251
# Mean corrected charge observed 122.43903321274001
# Ratio 3.459916667981708
# 129
# 56
# Total charge 6621.431394600785
# Standard deviation 70.37507537344936
# Maximum corrected charge observed 319.38559402240315
# Mean corrected charge observed 118.23984633215687
# Ratio 2.701167194730547
# 129
# 30
# Total charge 2950.4695720840823
# Standard deviation 64.84124438606074
# Maximum corrected charge observed 256.00559352012755
# Mean corrected charge observed 98.34898573613607
# Ratio 2.603032370938465
# 133
# 52
# Total charge 6122.622497788575
# Standard deviation 90.06836259208127
# Maximum corrected charge observed 444.8426342990596
# Mean corrected charge observed 117.74274034208798
# Ratio 3.7780896979858
# 127
# 31
# Total charge 4445.633382376109
# Standard deviation 117.62127063741433
# Maximum corrected charge observed 627.0549619520756
# Mean corrected charge observed 143.40752846374545
# Ratio 4.372538657275584
# 129
# 63
# Total charge 8645.244503065018
# Standard deviation 78.99841757189395
# Maximum corrected charge observed 402.0374241949567
# Mean corrected charge observed 137.22610322325426
# Ratio 2.929744522008898
# 128
# 28
# Total charge 3839.5364648881077
# Standard deviation 102.62954340421533
# Maximum corrected charge observed 362.46817876947006
# Mean corrected charge observed 137.12630231743242
# Ratio 2.64331621755829
# 195
# 88
# Total charge 15505.549932183183
# Standard deviation 341.1717614530457
# Maximum corrected charge observed 2576.9215643449834
# Mean corrected charge observed 176.19943104753617
# Ratio 14.625027725826003
# 131
# 27
# Total charge 2461.8960623821517
# Standard deviation 54.06244850270497
# Maximum corrected charge observed 181.01958918814253
# Mean corrected charge observed 91.1813356437834
# Ratio 1.9852702080975073
# 148
# 41
# Total charge 6073.78404744275
# Standard deviation 113.15245927462689
# Maximum corrected charge observed 641.4378118698856
# Mean corrected charge observed 148.14107432787196
# Ratio 4.329911976000855
# 128
# 71
# Total charge 9913.392961166468
# Standard deviation 100.31691103696652
# Maximum corrected charge observed 598.5748623324096
# Mean corrected charge observed 139.6252529741756
# Ratio 4.287010047123203
# 128
# 21
# Total charge 1802.8904351354315
# Standard deviation 61.79514227328225
# Maximum corrected charge observed 225.63904020592435
# Mean corrected charge observed 85.8519254826396
# Ratio 2.628235056318586
# 149
# 20
# Total charge 3111.682407327687
# Standard deviation 374.4702788120444
# Maximum corrected charge observed 1773.849158355871
# Mean corrected charge observed 155.58412036638435
# Ratio 11.40122240096638
# 129
# 84
# Total charge 11939.617664206475
# Standard deviation 104.88131663557724
# Maximum corrected charge observed 534.6884290187812
# Mean corrected charge observed 142.13830552626754
# Ratio 3.7617475953374817
# 129
# 78
# Total charge 10607.644700613811
# Standard deviation 85.40605431289751
# Maximum corrected charge observed 398.00943965743573
# Mean corrected charge observed 135.99544487966426
# Ratio 2.9266380209250014
# 149
# 11
# Total charge 1553.9449603412695
# Standard deviation 66.26032725134932
# Maximum corrected charge observed 284.26835382989515
# Mean corrected charge observed 141.26772366738814
# Ratio 2.012266825359195
# 129
# 60
# Total charge 8628.03636144994
# Standard deviation 133.61877676603106
# Maximum corrected charge observed 624.2186699404473
# Mean corrected charge observed 143.80060602416566
# Ratio 4.3408625818694215
# 126
# 22
# Total charge 2961.3640690957172
# Standard deviation 116.66801947362087
# Maximum corrected charge observed 527.2341767786157
# Mean corrected charge observed 134.60745768616897
# Ratio 3.9168273871410433
# 128
# 59
# Total charge 11089.972121485907
# Standard deviation 130.33676204787443
# Maximum corrected charge observed 583.9964614456719
# Mean corrected charge observed 187.96562917772724
# Ratio 3.1069321769113727
# 129
# 47
# Total charge 4323.573217165663
# Standard deviation 74.46388980493874
# Maximum corrected charge observed 398.0227380104013
# Mean corrected charge observed 91.99091951416304
# Ratio 4.326761164172527
# 127
# 32
# Total charge 2561.596679128161
# Standard deviation 67.70269549919793
# Maximum corrected charge observed 277.8574740613048
# Mean corrected charge observed 80.04989622275504
# Ratio 3.4710535200209396
# 128
# 27
# Total charge 2199.4166655373133
# Standard deviation 51.32881995963522
# Maximum corrected charge observed 220.30641035046054
# Mean corrected charge observed 81.45987650138197
# Ratio 2.704477588383319
# 133
# 37
# Total charge 5115.104872425332
# Standard deviation 97.81474455744029
# Maximum corrected charge observed 398.4237355747443
# Mean corrected charge observed 138.2460776331171
# Ratio 2.8819894379361486
# 129
# 54
# Total charge 4675.174344249404
# Standard deviation 70.86270206192604
# Maximum corrected charge observed 314.0969894047333
# Mean corrected charge observed 86.57730267128527
# Ratio 3.6279368808391914
# 131
# 35
# Total charge 3860.817890598868
# Standard deviation 123.28046142539247
# Maximum corrected charge observed 729.5104418523557
# Mean corrected charge observed 110.30908258853908
# Ratio 6.613330695292634
# 149
# 46
# Total charge 5125.203086757704
# Standard deviation 128.1816028984957
# Maximum corrected charge observed 695.0506141438805
# Mean corrected charge observed 111.41745840777618
# Ratio 6.238255871894585
# 129
# 69
# Total charge 13401.183351038791
# Standard deviation 598.7418707883263
# Maximum corrected charge observed 5018.616123208405
# Mean corrected charge observed 194.2200485657796
# Ratio 25.839845887530352
# 132
# 23
# Total charge 1793.9847805146528
# Standard deviation 63.95263565914774
# Maximum corrected charge observed 291.8293002986399
# Mean corrected charge observed 77.99933828324578
# Ratio 3.7414330265071585
# 128
# 56
# Total charge 41028.775615405335
# Standard deviation 437.3316191483118
# Maximum corrected charge observed 2495.7725897739692
# Mean corrected charge observed 732.6567074179524
# Ratio 3.40646931162295
# 127
# 28
# Total charge 2742.716261165325
# Standard deviation 61.78891696681996
# Maximum corrected charge observed 252.33671427709137
# Mean corrected charge observed 97.95415218447589
# Ratio 2.5760696065427493
# 128
# 20
# Total charge 2427.369623490873
# Standard deviation 104.30754267990415
# Maximum corrected charge observed 389.0802226032419
# Mean corrected charge observed 121.36848117454365
# Ratio 3.205776481982122
# 147
# 11
# Total charge 853.0977768421797
# Standard deviation 68.9154896946365
# Maximum corrected charge observed 262.937142279047
# Mean corrected charge observed 77.55434334928906
# Ratio 3.390359984028636
# 129
# 140
# Total charge 162809.4975008594
# Standard deviation 1712.9100382059669
# Maximum corrected charge observed 14001.974225344431
# Mean corrected charge observed 1162.9249821489957
# Ratio 12.040307363136925
# 128
# 35
# Total charge 12223.531091761593
# Standard deviation 443.74599430220445
# Maximum corrected charge observed 1898.5384737862828
# Mean corrected charge observed 349.24374547890267
# Ratio 5.436141658551107
# 129
# 58
# Total charge 6096.606628511758
# Standard deviation 76.42408836593502
# Maximum corrected charge observed 349.2777625175549
# Mean corrected charge observed 105.11390738813375
# Ratio 3.322850146059594
# 147
# 11
# Total charge 903.4042695459473
# Standard deviation 46.81506855579117
# Maximum corrected charge observed 185.28371671557818
# Mean corrected charge observed 82.12766086781339
# Ratio 2.2560452198169525
# 128
# 37
# Total charge 3386.523575717319
# Standard deviation 67.55774292919523
# Maximum corrected charge observed 287.8455355921921
# Mean corrected charge observed 91.5276642085762
# Ratio 3.1449020149387885
# 129
# 64
# Total charge 5877.29586671461
# Standard deviation 79.76108958470932
# Maximum corrected charge observed 505.87560769996486
# Mean corrected charge observed 91.83274791741579
# Ratio 5.5086624235059745
# 129
# 89
# Total charge 7627.419513601408
# Standard deviation 59.42197014559539
# Maximum corrected charge observed 284.63048074998045
# Mean corrected charge observed 85.70134284945402
# Ratio 3.321190442137789
# 172
# 37
# Total charge 7013.890127738683
# Standard deviation 101.61301210064221
# Maximum corrected charge observed 401.3381304910446
# Mean corrected charge observed 189.56459804699142
# Ratio 2.117157605512166
# 128
# 52
# Total charge 4592.2024424801075
# Standard deviation 83.90121237010794
# Maximum corrected charge observed 556.9906338962069
# Mean corrected charge observed 88.31158543230976
# Ratio 6.307107172514035
# 132
# 74
# Total charge 7446.877394611657
# Standard deviation 70.89689757564558
# Maximum corrected charge observed 403.69928817512124
# Mean corrected charge observed 100.63347830556293
# Ratio 4.0115803902686435
# 127
# 25
# Total charge 2102.3665571405163
# Standard deviation 56.652948589151656
# Maximum corrected charge observed 241.74682830009516
# Mean corrected charge observed 84.09466228562066
# Ratio 2.874698842109881
# 129
# 48
# Total charge 35824.68970512497
# Standard deviation 418.34214911214843
# Maximum corrected charge observed 2486.4101472946772
# Mean corrected charge observed 746.3477021901035
# Ratio 3.3314367284825637
# 149
# 51
# Total charge 5344.76096637343
# Standard deviation 67.3095887540234
# Maximum corrected charge observed 394.06113725746485
# Mean corrected charge observed 104.79923463477314
# Ratio 3.7601528162946383
# 133
# 32
# Total charge 3279.979367804882
# Standard deviation 86.67659420415507
# Maximum corrected charge observed 398.628858329202
# Mean corrected charge observed 102.49935524390256
# Ratio 3.889086496013988
# 127
# 8
# Total charge 427.8224903805572
# Standard deviation 14.599925832067417
# Maximum corrected charge observed 75.77805215269673
# Mean corrected charge observed 53.47781129756965
# Ratio 1.4169998792777918
# 133
# 38
# Total charge 3488.525543514256
# Standard deviation 73.02125007094499
# Maximum corrected charge observed 296.37204507923803
# Mean corrected charge observed 91.80330377669094
# Ratio 3.228337465938645
# 129
# 45
# Total charge 6759.943860694854
# Standard deviation 179.46319275664607
# Maximum corrected charge observed 1138.9351880308686
# Mean corrected charge observed 150.22097468210788
# Ratio 7.581732114580148
# 134
# 106
# Total charge 10752.51353459009
# Standard deviation 71.24187862214245
# Maximum corrected charge observed 482.7725560161612
# Mean corrected charge observed 101.4388069300952
# Ratio 4.7592491535202655
# 129
# 45
# Total charge 4011.46377773334
# Standard deviation 74.00965138545588
# Maximum corrected charge observed 331.27084911026327
# Mean corrected charge observed 89.14363950518533
# Ratio 3.7161467823062555
# 129
# 99
# Total charge 13472.951773625455
# Standard deviation 103.62894782540394
# Maximum corrected charge observed 569.0069323948179
# Mean corrected charge observed 136.09042195581267
# Ratio 4.181094629712952
# 128
# 29
# Total charge 4157.737226469557
# Standard deviation 100.37407112282506
# Maximum corrected charge observed 493.1370917915944
# Mean corrected charge observed 143.3702491886054
# Ratio 3.43960545916933
# 129
# 76
# Total charge 9139.94205960851
# Standard deviation 90.06592447038196
# Maximum corrected charge observed 546.2869151343782
# Mean corrected charge observed 120.26239552116459
# Ratio 4.542458286873547
# 154
# 43
# Total charge 4742.483077870774
# Standard deviation 62.81346601708524
# Maximum corrected charge observed 300.926090734946
# Mean corrected charge observed 110.29030413652963
# Ratio 2.728490895830935
# 181
# 79
# Total charge 12758.295979491295
# Standard deviation 105.98689007639774
# Maximum corrected charge observed 471.52667125807443
# Mean corrected charge observed 161.49741746191512
# Ratio 2.919716480105767
# 130
# 52
# Total charge 5769.594102480334
# Standard deviation 75.66985868453037
# Maximum corrected charge observed 288.5341818917126
# Mean corrected charge observed 110.95373274000643
# Ratio 2.6004909863449437
# 128
# 35
# Total charge 3057.38624735516
# Standard deviation 73.49876851694184
# Maximum corrected charge observed 306.20028703899936
# Mean corrected charge observed 87.353892781576
# Ratio 3.5052849654295057
# 132
# 29
# Total charge 3692.8645775740656
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-147-d9d0fd45c16a> in <module>
#       7             print(len(func(frame)))
#       8             print('Total charge', np.sum(func(frame)) )
# ----> 9             print('Standard deviation', np.std(func(frame)))
#      10             print('Maximum corrected charge observed', np.max(func(frame)) )
#      11             print('Mean corrected charge observed', np.mean(func(frame)) )
#
# <ipython-input-145-3f36df684e95> in func(frame)
#      14     gfile = dataio.I3File(gcd_file)
#      15     gframe = gfile.pop_frame()
# ---> 16     geometry = gframe['I3Geometry']
#      17
#      18     mydom = []
#
# KeyboardInterrupt:

# %%
def inf(num):
    infile = dataio.I3File(os.path.join(files_dir,file_list[num]))
    frame = infile.pop_physics()   
    return frame

# %%
print(inf(0))
# Out:
# [ I3Frame  (Physics):
#   'AnalysisMuons' [Physics] ==> TreeBase::Tree<I3Particle, I3ParticleID, __gnu_cxx::hash<I3ParticleID> > (174)
#   'BackgroundCLSim_intermediatePhotons' [DAQ] ==> I3Map<ModuleKey, I3Vector<I3Photon> > (3167)
#   'BackgroundI3MCPESeriesMap_0.990' [DAQ] ==> I3Map<OMKey, vector<I3MCPE> > (90)
#   'BackgroundI3MCTree' [DAQ] ==> TreeBase::Tree<I3Particle, I3ParticleID, __gnu_cxx::hash<I3ParticleID> > (1786)
#   'BackgroundI3MCTree_preMuonProp' [DAQ] ==> TreeBase::Tree<I3Particle, I3ParticleID, __gnu_cxx::hash<I3ParticleID> > (918)
#   'BackgroundMMCTrackList' [DAQ] ==> I3Vector<I3MMCTrack> (304)
#   'BeaconLaunches' [DAQ] ==> I3Map<OMKey, vector<I3DOMLaunch> > (46)
#   'CalibratedWaveformRange' [DAQ] ==> I3TimeWindow (48)
#   'CascadeFilter_13' [Physics] ==> I3PODHolder<bool> (27)
#   'CorsikaInteractionHeight' [DAQ] ==> I3PODHolder<double> (36)
#   'CorsikaWeightMap' [DAQ] ==> I3Map<string, double> (482)
#   'DCAnalysisHits' [Physics] ==> I3PODHolder<double> (36)
#   'DCNHits' [Physics] ==> I3PODHolder<double> (36)
#   'DSTTriggers' [DAQ] ==> I3SuperDSTTriggerSeries (64)
#   'DebiasingForLineFitNew' [Physics] ==> I3RecoPulseSeriesMapMask (213)
#   'DeepCoreFilter_13' [Physics] ==> I3PODHolder<bool> (27)
#   'DeepCoreFilter_TwoLayerExp_13' [Physics] ==> I3PODHolder<bool> (27)
#   'DeepCoreSMTTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'DistAboveEndpoint' [Physics] ==> I3Vector<double> (646)
#   'DistToBorder' [Physics] ==> I3PODHolder<double> (36)
#   'EHEFilter_13' [Physics] ==> I3PODHolder<bool> (27)
#   'EventCharge' [Physics] ==> I3PODHolder<double> (36)
#   'FSSCandidate_13' [Physics] ==> I3PODHolder<bool> (27)
#   'FSSFilter_13' [Physics] ==> I3PODHolder<bool> (27)
#   'FSSFilter_STWC_pulsesTimeRange' [Physics] ==> I3TimeWindow (48)
#   'FilterMask' [Physics] ==> I3Map<string, I3FilterResult> (891)
#   'FiniteRecoCutsDOMeff' [Physics] ==> I3FiniteCuts (80)
#   'FiniteRecoFitDOMeff' [Physics] ==> I3Particle (150)
#   'FiniteRecoLLHRatio' [Physics] ==> I3PODHolder<double> (36)
#   'FiniteRecoLlhDOMeff' [Physics] ==> I3StartStopParams (61)
#   'FiniteReco_FiniteRecoLlhDOMeff_rusage' [Physics] ==> I3RUsage (52)
#   'FiniteReco_VertexRecoDOMeff_rusage' [Physics] ==> I3RUsage (52)
#   'FixedRateTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'GCFilter_13' [Physics] ==> I3PODHolder<bool> (27)
#   'HESEFilter_15' [Physics] ==> I3PODHolder<bool> (27)
#   'HitMultiplicityValues' [Physics] ==> I3HitMultiplicityValues (63)
#   'HitStatisticsValues' [Physics] ==> I3HitStatisticsValues (155)
#   'I3EventHeader' [Physics] ==> I3EventHeader (109)
#   'I3MCPESeriesMap_0.990' [DAQ] ==> I3Map<OMKey, vector<I3MCPE> > (7081)
#   'I3MCPESeriesMap_0.990WithoutNoise' [DAQ] ==> I3Map<OMKey, vector<I3MCPE> > (3184)
#   'I3MCPulseSeriesMap' [DAQ] ==> I3Map<OMKey, vector<I3MCPulse> > (5594)
#   'I3MCPulseSeriesMapParticleIDMap' [DAQ] ==> I3Map<OMKey, map<I3ParticleID, vector<unsigned int, allocator<unsigned int> >, less<I3ParticleID>, allocator<pair<I3ParticleID const, vector<unsigned int, allocator<unsigned int> > > > > > (5521)
#   'I3MCTree' [DAQ] ==> TreeBase::Tree<I3Particle, I3ParticleID, __gnu_cxx::hash<I3ParticleID> > (6630)
#   'I3SuperDST' [DAQ] ==> I3SuperDST (469)
#   'I3TriggerHierarchy' [Physics] ==> I3Tree<I3Trigger> (440)
#   'I3Triggers' [DAQ] ==> I3Tree<I3Trigger> (230)
#   'ICAnalysisHits' [Physics] ==> I3PODHolder<double> (36)
#   'ICNHits' [Physics] ==> I3PODHolder<double> (36)
#   'IceTopSMTTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'IceTopVolumeTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'ImpactAngle' [Physics] ==> I3Vector<double> (646)
#   'InIceDSTPulses' [DAQ] ==> I3RecoPulseSeriesMapMask (416)
#   'InIcePulses' [DAQ] ==> I3RecoPulseSeriesMapMask (420)
#   'InIceRawData' [DAQ] ==> I3Map<OMKey, vector<I3DOMLaunch> > (15140)
#   'InIceSMTTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'InIceStringTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'L4VetoLayer0' [Physics] ==> I3PODHolder<double> (36)
#   'L4VetoLayer1' [Physics] ==> I3PODHolder<double> (36)
#   'L4VetoLayerPulses0' [Physics] ==> I3RecoPulseSeriesMapMask (102)
#   'L4VetoLayerPulses1' [Physics] ==> I3RecoPulseSeriesMapMask (102)
#   'L4VetoLayerQTot' [Physics] ==> I3PODHolder<double> (36)
#   'L4VetoLayerVertexTime' [Physics] ==> I3PODHolder<double> (36)
#   'LineFitDOMeff' [Physics] ==> I3Particle (150)
#   'LineFitDOMeffParams' [Physics] ==> I3LineFitParams (71)
#   'LowUp_13' [Physics] ==> I3PODHolder<bool> (27)
#   'MESEFilter_15' [Physics] ==> I3PODHolder<bool> (27)
#   'MMCTrackList' [DAQ] ==> I3Vector<I3MMCTrack> (304)
#   'MPEFitCramerRaoDOMeffParams' [Physics] ==> CramerRaoParams (135)
#   'MPEFitDOMeff' [Physics] ==> I3Particle (150)
#   'MPEFitDOMeffFitParams' [Physics] ==> I3LogLikelihoodFitParams (68)
#   'MuEx' [Physics] ==> I3Particle (150)
#   'MuEx_EnUnc' [Physics] ==> I3PODHolder<double> (36)
#   'MuEx_Sigma' [Physics] ==> I3PODHolder<double> (36)
#   'MuEx_r' [Physics] ==> I3PODHolder<double> (36)
#   'MuEx_rlle' [Physics] ==> I3PODHolder<double> (36)
#   'MuEx_rllt' [Physics] ==> I3PODHolder<double> (36)
#   'MuonFilter_13' [Physics] ==> I3PODHolder<bool> (27)
#   'NDirDoms' [Physics] ==> I3PODHolder<double> (36)
#   'NumVisibleMuons_analysis_region' [Physics] ==> I3PODHolder<double> (36)
#   'OM' [Physics] ==> I3Vector<double> (646)
#   'PhotonArrivalAngle' [Physics] ==> I3Vector<double> (646)
#   'PhysMinBiasTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'PoleEHESummaryPulseInfo' [Physics] ==> I3PortiaEvent (172)
#   'PoleMuonLinefit' [Physics] ==> I3Particle (150)
#   'PoleMuonLinefitParams' [Physics] ==> I3LineFitParams (71)
#   'PoleMuonLlhFit' [Physics] ==> I3Particle (150)
#   'PoleMuonLlhFitDirectHitsBaseA' [Physics] ==> I3DirectHitsValues (126)
#   'PoleMuonLlhFitDirectHitsBaseB' [Physics] ==> I3DirectHitsValues (126)
#   'PoleMuonLlhFitDirectHitsBaseC' [Physics] ==> I3DirectHitsValues (126)
#   'PoleMuonLlhFitDirectHitsBaseD' [Physics] ==> I3DirectHitsValues (126)
#   'PoleMuonLlhFitFitParams' [Physics] ==> I3LogLikelihoodFitParams (68)
#   'PoleMuonLlhFitMuE' [Physics] ==> I3Particle (150)
#   'PoleMuonLlhFit_Finite' [Physics] ==> I3Particle (150)
#   'PoleMuonLlhFit_FiniteCuts' [Physics] ==> I3FiniteCuts (80)
#   'PolyplopiaInfo' [DAQ] ==> I3Map<string, double> (69)
#   'PolyplopiaPrimary' [DAQ] ==> I3Particle (150)
#   'PrimaryParticle' [DAQ] ==> I3Particle (150)
#   'RNGState' [DAQ] ==> I3SPRNGRandomServiceState (73)
#   'RTTWOfflinePulses_FR_WIMP_DOMeff' [Physics] ==> I3RecoPulseSeriesMapMask (335)
#   'RecoDistance' [Physics] ==> I3Vector<double> (646)
#   'RecoEndpoint' [Physics] ==> I3Position (54)
#   'RecoEndpointZ' [Physics] ==> I3PODHolder<double> (36)
#   'SPEFit2DOMeff' [Physics] ==> I3Particle (150)
#   'SPEFit2DOMeffFitParams' [Physics] ==> I3LogLikelihoodFitParams (68)
#   'SPEFitSingleDOMeff' [Physics] ==> I3Particle (150)
#   'SPEFitSingleDOMeffFitParams' [Physics] ==> I3LogLikelihoodFitParams (68)
#   'SRTInIcePulsesDOMeff' [Physics] ==> I3RecoPulseSeriesMapMask (290)
#   'ScintMinBiasTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'SignalCLSim_intermediatePhotons' [DAQ] ==> I3Map<ModuleKey, I3Vector<I3Photon> > (82751)
#   'SignalI3MCPESeriesMap_0.990' [DAQ] ==> I3Map<OMKey, vector<I3MCPE> > (3143)
#   'SlowParticleTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'SplineMPE' [Physics] ==> I3Particle (150)
#   'SplineMPEDirectHitsA' [Physics] ==> I3DirectHitsValues (126)
#   'SplineMPEDirectHitsB' [Physics] ==> I3DirectHitsValues (126)
#   'SplineMPEDirectHitsC' [Physics] ==> I3DirectHitsValues (126)
#   'SplineMPEDirectHitsD' [Physics] ==> I3DirectHitsValues (126)
#   'SplineMPEFitParams' [Physics] ==> I3LogLikelihoodFitParams (68)
#   'SplitInIceDSTPulses' [Physics] ==> I3RecoPulseSeriesMapMask (420)
#   'SplitInIcePulses' [Physics] ==> I3RecoPulseSeriesMapMask (425)
#   'SplitUncleanedInIcePulsesHLC_NoDC' [Physics] ==> I3RecoPulseSeriesMapMask (158)
#   'String' [Physics] ==> I3Vector<double> (646)
#   'TWOfflinePulses_FR_WIMP_DOMeff' [Physics] ==> I3RecoPulseSeriesMapMask (382)
#   'TWOfflinePulses_FR_WIMP_DOMeffTimeRange' [Physics] ==> I3TimeWindow (48)
#   'TimeShift' [DAQ] ==> I3PODHolder<double> (36)
#   'TotalCharge' [Physics] ==> I3Vector<double> (646)
#   'TriggerSplitterLaunchWindow' [Physics] ==> I3TimeWindow (48)
#   'TruthDistance' [Physics] ==> I3Vector<double> (646)
#   'TruthEndpoint' [Physics] ==> I3Position (54)
#   'TruthEnergy' [Physics] ==> I3PODHolder<double> (36)
#   'TruthMuon' [Physics] ==> I3Particle (150)
#   'VEF_13' [Physics] ==> I3PODHolder<bool> (27)
#   'VolumeTrigTriggered' [Physics] ==> I3PODHolder<bool> (27)
#   'rlogl' [Physics] ==> I3PODHolder<double> (36)
# ]

# %%
pulses = inf(0)['SRTInIcePulsesDOMeff'].apply(inf(0))
one_dom = pulses.items()

# %%
charge = []
for i in range(16):  #Sasha: I have 16 here, because it is the first time when we met this "triplet" 
    
    for pulse in one_dom[i][1]:
        char = 0
        char += pulse.charge
        print(char) #Sasha: there are three last values of charge
    charge.append(char) #Sasha: they do not write down in this array, only one of them is written.  
        
print(charge)
#Sasha: but in the next cell I consider them as a sum, I mean I will have not 1.17, 0.925, 1.225 separately, but their sum
# Out:
# 0.824999988079071
# 1.1749999523162842
# 0.875
# 0.824999988079071
# 0.2750000059604645
# 1.475000023841858
# 1.1749999523162842
# 0.824999988079071
# 1.125
# 1.5750000476837158
# 1.4249999523162842
# 0.32499998807907104
# 1.0750000476837158
# 1.475000023841858
# 0.875
# 1.1749999523162842
# 0.925000011920929
# 1.225000023841858
# [0.824999988079071, 1.1749999523162842, 0.875, 0.824999988079071, 0.2750000059604645, 1.475000023841858, 1.1749999523162842, 0.824999988079071, 1.125, 1.5750000476837158, 1.4249999523162842, 0.32499998807907104, 1.0750000476837158, 1.475000023841858, 0.875, 1.225000023841858]

# %%
charge = []
for i in range(len(one_dom)):  
    char = 0
    for pulse in one_dom[i][1]:
        char += pulse.charge
        
        
    charge.append(char)
        
print(charge)
# Out:
# [0.824999988079071, 1.1749999523162842, 0.875, 0.824999988079071, 0.2750000059604645, 1.475000023841858, 1.1749999523162842, 0.824999988079071, 1.125, 1.5750000476837158, 1.4249999523162842, 0.32499998807907104, 1.0750000476837158, 1.475000023841858, 0.875, 3.324999988079071, 0.625, 3.3000000715255737, 1.125, 0.7749999761581421, 1.375, 0.925000011920929, 1.0750000476837158, 0.675000011920929, 1.375, 1.3250000476837158, 1.0750000476837158, 1.3499999642372131, 1.375, 0.875, 2.649999976158142, 0.7250000238418579, 0.4749999940395355, 1.4249999523162842, 0.7749999761581421, 1.024999976158142, 1.4249999523162842, 0.7250000238418579, 0.22499999403953552, 1.125, 1.1749999523162842, 1.274999976158142, 0.875, 0.925000011920929, 0.42500001192092896, 0.875, 2.574999988079071, 0.875, 2.900000035762787, 3.774999976158142, 3.475000113248825]

# %%
gcd_file = '/cvmfs/icecube.opensciencegrid.org/data/GCD/GeoCalibDetectorStatus_IC86_Merged.i3.gz'

gfile = dataio.I3File(gcd_file)
gframe = gfile.pop_frame()
print(gframe)
geometry = gframe['I3Geometry']
# Out:
# [ I3Frame  (Geometry):
#   'I3Geometry' [Geometry] ==> I3Geometry (641528)
# ]

# %%
mydom = []
for i in range(len(one_dom)):
    dom = geometry.omgeo[one_dom[i][0]]    
    mydom.append(dom)  
    
print(len(mydom))
#print(mydom[0])
# Out:
# 51

# %%
mmctracks = inf(0)['MMCTrackList']
track = mmctracks[0].particle
print(track)
# Out:
# [ I3Particle MajorID : 13469127016857373990
#              MinorID : 846
#               Zenith : 0.400847
#              Azimuth : 1.80333
#                    X : -227.484
#                    Y : 1017.22
#                    Z : 1949.99
#                 Time : 3536.68
#               Energy : 1054.01
#                Speed : 0.299792
#               Length : 3125.59
#                 Type : MuPlus
#         PDG encoding : -13
#                Shape : StartingTrack
#               Status : NotSet
#             Location : InIce
# ]

# %%
distance = []
for i in range(len(mydom)):
    d = phys_services.I3Calculator.cherenkov_distance(track, mydom[i].position)
    distance.append(d)
print(len(distance))
# Out:
# 51

# %%
corrected_charge = []
for i in range(len(distance)):
# This is for adding also the attenuation (absorption + scattering)
    att_length = 50. # Typical attenuation length in icecube
    corrected = charge[i]*distance[i]#*np.exp(distance/att_length)
    corrected_charge.append(corrected)

# %%
print(len(corrected_charge))
print(corrected_charge)
# Out:
# 51
# [222.0763055078901, 167.65234550125294, 90.87879437146664, 70.22624541320249, 32.3280058807941, 87.84635247531457, 58.48567357188964, 43.853323474581885, 199.65093749494238, 205.83572456677518, 101.78875708003031, 20.087685112520425, 56.326474720920636, 63.917247745306305, 30.530444785473144, 91.92426364795048, 14.230792672602277, 84.02980064662638, 145.34649795757636, 111.39816999261477, 420.42546298068703, 200.25207647815236, 175.6844459128978, 94.48273255331011, 161.179778497579, 140.79109625569555, 110.38414462387806, 80.54971137983249, 79.88749828800925, 48.8141967257675, 155.96482979729348, 45.35664547689054, 75.50349198575303, 351.0134498294823, 153.79620421796307, 200.1332633587479, 269.3021013764831, 134.78485505776138, 48.89932423766513, 115.99762021723895, 98.24075255388614, 101.74091060807486, 63.26580603753744, 63.48418668450139, 23.245831617524548, 39.831076130185615, 110.32993059738524, 35.376758412388426, 106.06636885481633, 128.34913355697762, 118.64307049674646]

# %%
# Try to put it inside a function so that you can pass the puse series to the function, 
# and obtain a list of corrected charges
# Consider looking only at DOMs "nearby" (within a maximum distance of 150-200m, no further)

# %%
phys_services.I3Calculator.closest_approach_distance
# Out:
# <function phys-services.I3Calculator.closest_approach_distance>

# %%
nfiles = 2

char = []

for i in range(nfiles):
    with dataio.I3File(os.path.join(files_dir, file_list[i])) as infile:
        for frame in infile:  
            frame = infile.pop_physics()             
            fr.append(frame)
            pulses = frame['SRTInIcePulsesDOMeff'].apply(frame)
        
print(len(pulses))
#print(pulses)
zero = []
one = []


for i in range(len(pulses)):
    one_dom = pulses.popitem()
   
    charge = 0
    for pulse in one_dom[1]:
        charge += pulse.charge
    #print(charge)
    char.append(charge)
    zero.append(one_dom[0])
    one.append(one_dom[1])
    #print(one_dom[0])
    
print(len(char))
#print(char)
#print(zero)
# Out:
# 88
# 88

# %%
gcd_file = '/cvmfs/icecube.opensciencegrid.org/data/GCD/GeoCalibDetectorStatus_IC86_Merged.i3.gz'

gfile = dataio.I3File(gcd_file)

dom=[]
tr=[]
dist = []


for i in range(nfiles):
    with dataio.I3File(os.path.join(files_dir, file_list[i])) as infile:
        for frame in infile:  
            frame = infile.pop_physics()             
            fr.append(frame)
        
            mmctracks = frame['MMCTrackList']
            track = mmctracks[0].particle
            tr.append(track)
        
        gframe = gfile.pop_frame()    
        geometry = gframe['I3Geometry']

for j in range(len(zero)):
    mydom = geometry.omgeo[zero[j]]
    dom.append(mydom)
           
    distance = phys_services.I3Calculator.cherenkov_distance(track, mydom.position)
    dist.append(distance)
        
print(len(dist))    
print(len(tr))
print(len(dom))
# Out:
# 88
# 2588
# 88

# %%
def cor_char(char, dist):

  corrected_charge = char * dist
  return corrected_charge

cor_char(5,10)
# Out:
# 50

# %%
# Out:
# 50

# %%
list_of_char = []

for charge in range(2):
    for distance in range(2):
        list_of_char.append(cor_char(charge,distance))

# %%
print(list_of_char)
# Out:
# [0, 0, 0, 1]
